# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import time
import re
import os
import sqlite3

import requests
import yfinance as yf

import string
import random 
import unidecode
from bs4 import BeautifulSoup

import settings

# %% [markdown]
# ### Hash Request

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import pandas as pd
from urllib.parse import urlencode

# Define the base URL and headers
base_url = "https://www.rad.cvm.gov.br/ENET/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36",
    "Referer": "https://www.rad.cvm.gov.br/",
}

# Options mapping (hardcoded as per known structure)
options_mapping = {
    "Dados da Empresa": [
        {"url_base": "frmDadosComposicaoCapitalITR.aspx", "Quadro": "Composição do Capital"},
        {"url_base": "frmDadosProventoDinheiroITR.aspx", "Quadro": "Proventos em Dinheiro"},
    ],
    "DFs Individuais": [
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "2", "Quadro": "Balanço Patrimonial Ativo"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "3", "Quadro": "Balanço Patrimonial Passivo"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "4", "Quadro": "Demonstração do Resultado"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "5", "Quadro": "Demonstração do Resultado Abrangente"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "99", "Quadro": "Demonstração do Fluxo de Caixa"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "1", "Demonstracao": "9", "Quadro": "Demonstração de Valor Adicionado"},
    ],
    "DFs Consolidadas": [
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "2", "Quadro": "Balanço Patrimonial Ativo"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "3", "Quadro": "Balanço Patrimonial Passivo"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "4", "Quadro": "Demonstração do Resultado"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "5", "Quadro": "Demonstração do Resultado Abrangente"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "99", "Quadro": "Demonstração do Fluxo de Caixa"},
        {"url_base": "frmDemonstracaoFinanceiraITR.aspx", "Informacao": "2", "Demonstracao": "9", "Quadro": "Demonstração de Valor Adicionado"},
    ],
}

# List of nsds
nsds = ["142690", "88769"]

# Initialize a list to store all rows
rows = []

# Iterate over each nsd
for nsd in nsds:
    main_url = f"https://www.rad.cvm.gov.br/ENET/frmGerenciaPaginaFRE.aspx?NumeroSequencialDocumento={nsd}&CodigoTipoInstituicao=1"
    
    # Make the GET request
    response = requests.get(main_url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch data for NSD: {nsd}")
        continue

    # Parse the HTML
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Extract `NumeroSequencialRegistroCvm` from JavaScript content
    script_tag = soup.find("script", string=re.compile("NumeroSequencialRegistroCvm"))
    if script_tag:
        script_content = script_tag.string
        registro_cvm_match = re.search(r"NumeroSequencialRegistroCvm=(\d+)", script_content)
        registro_cvm = registro_cvm_match.group(1) if registro_cvm_match else None
    else:
        registro_cvm = None
    
    if not registro_cvm:
        print(f"Failed to extract NumeroSequencialRegistroCvm for NSD: {nsd}")
        continue
    
    # Extract company information
    data = {
        "nsd": nsd,
        "main_url": main_url,
        "company_name": soup.select_one("#lblNomeCompanhia").text.strip(),
        "dri_name": soup.select_one("#lblNomeDRI").text.split(" - ")[0].strip(),
        "category": soup.select_one("#lblDescricaoCategoria").text.split(" - ")[0].strip(),
        "category_date": datetime.strptime(soup.select_one("#lblDescricaoCategoria").text.split(" - ")[1], "%d/%m/%Y"),
        "category_version": soup.select_one("#lblDescricaoCategoria").text.split(" - ")[2].strip(),
        "auditor_name": soup.select_one("#lblAuditor").text.split(" - ")[0].strip(),
        "responsible_technician": soup.select_one("#lblResponsavelTecnico").text.strip(),
        "protocol_number": soup.select_one("#lblProtocolo").text.strip(),
        "document_date": datetime.strptime(soup.select_one("#lblDataDocumento").text.strip(), "%d/%m/%Y"),
        "submission_date": datetime.strptime(soup.select_one("#lblDataEnvio").text.strip(), "%d/%m/%Y %H:%M:%S"),
        "cancellation_reason": soup.select_one("#lblMotivoCancelamentoReapresentacao").text.strip() if soup.select_one("#lblMotivoCancelamentoReapresentacao") else None,
        "hash": soup.select_one("#hdnHash")["value"].strip(),
    }
    
    # Generate URLs for all groups and options
    for group, options in options_mapping.items():
        for option in options:
            params = {
                "Informacao": option.get("Informacao"),
                "Demonstracao": option.get("Demonstracao"),
                "Periodo": option.get("Periodo", "0"),
                "Grupo": group.replace(" ", "+"),
                "Quadro": option.get("Quadro", "").replace(" ", "+"),
                "NomeTipoDocumento": "ITR" if group != "Dados da Empresa" else "DFP",
                "Empresa": data["company_name"].replace(" ", "%20"),
                "DataReferencia": data["category_date"].strftime("%Y-%m-%d"),
                "Versao": "1" if group != "Dados da Empresa" else "V1",
                "CodTipoDocumento": "3" if group != "Dados da Empresa" else "4",
                "NumeroSequencialDocumento": nsd,
                "NumeroSequencialRegistroCvm": registro_cvm,
                "CodigoTipoInstituicao": "1",
                "Hash": data["hash"],
            }
            # Add additional params from the option
            params.update({k: v for k, v in option.items() if k not in ["url_base", "Quadro"]})
            
            # Construct the full URL
            query_string = urlencode(params, safe="+")
            full_url = f"{base_url}{option['url_base']}?{query_string}"
            
            # Add a row to the rows list
            rows.append({
                **data,
                "group": group,
                "url_base": option["url_base"],
                "quadro": option.get("Quadro", ""),
                "informacao": option.get("Informacao"),
                "demonstracao": option.get("Demonstracao"),
                "periodo": option.get("Periodo"),
                "full_url": full_url,
            })

# Create a DataFrame
df = pd.DataFrame(rows)

# Reorder columns
preferred_order = [
    "nsd", "company_name", "main_url", "url_base", "group", "quadro", 
    "informacao", "demonstracao", "periodo", "category", 
    "category_date", "document_date", "submission_date", 
    "dri_name", "auditor_name", "responsible_technician", 
    "cancellation_reason", "category_version", "protocol_number", "hash", "full_url", 
]
df = df[preferred_order]

# %%
df
# Out:
#        nsd              company_name  \
# 0   142690         LOJAS RENNER S.A.
# 1   142690         LOJAS RENNER S.A.
# 2   142690         LOJAS RENNER S.A.
# 3   142690         LOJAS RENNER S.A.
# 4   142690         LOJAS RENNER S.A.
# 5   142690         LOJAS RENNER S.A.
# 6   142690         LOJAS RENNER S.A.
# 7   142690         LOJAS RENNER S.A.
# 8   142690         LOJAS RENNER S.A.
# 9   142690         LOJAS RENNER S.A.
# 10  142690         LOJAS RENNER S.A.
# 11  142690         LOJAS RENNER S.A.
# 12  142690         LOJAS RENNER S.A.
# 13  142690         LOJAS RENNER S.A.
# 14   88769  Localiza Rent a Car S.A.
# 15   88769  Localiza Rent a Car S.A.
# 16   88769  Localiza Rent a Car S.A.
# 17   88769  Localiza Rent a Car S.A.
# 18   88769  Localiza Rent a Car S.A.
# 19   88769  Localiza Rent a Car S.A.
# 20   88769  Localiza Rent a Car S.A.
# 21   88769  Localiza Rent a Car S.A.
# 22   88769  Localiza Rent a Car S.A.
# 23   88769  Localiza Rent a Car S.A.
# 24   88769  Localiza Rent a Car S.A.
# 25   88769  Localiza Rent a Car S.A.
# 26   88769  Localiza Rent a Car S.A.
# 27   88769  Localiza Rent a Car S.A.
#
#                                              main_url  \
# 0   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 1   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 2   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 3   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 4   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 5   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 6   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 7   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 8   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 9   https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 10  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 11  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 12  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 13  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 14  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 15  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 16  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 17  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 18  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 19  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 20  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 21  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 22  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 23  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 24  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 25  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 26  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
# 27  https://www.rad.cvm.gov.br/ENET/frmGerenciaPag...
#
#                              url_base             group  \
# 0   frmDadosComposicaoCapitalITR.aspx  Dados da Empresa
# 1    frmDadosProventoDinheiroITR.aspx  Dados da Empresa
# 2   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 3   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 4   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 5   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 6   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 7   frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 8   frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 9   frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 10  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 11  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 12  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 13  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 14  frmDadosComposicaoCapitalITR.aspx  Dados da Empresa
# 15   frmDadosProventoDinheiroITR.aspx  Dados da Empresa
# 16  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 17  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 18  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 19  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 20  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 21  frmDemonstracaoFinanceiraITR.aspx   DFs Individuais
# 22  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 23  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 24  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 25  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 26  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
# 27  frmDemonstracaoFinanceiraITR.aspx  DFs Consolidadas
#
#                                   quadro informacao demonstracao periodo  \
# 0                  Composição do Capital       None         None    None
# 1                  Proventos em Dinheiro       None         None    None
# 2              Balanço Patrimonial Ativo          1            2    None
# 3            Balanço Patrimonial Passivo          1            3    None
# 4              Demonstração do Resultado          1            4    None
# 5   Demonstração do Resultado Abrangente          1            5    None
# 6         Demonstração do Fluxo de Caixa          1           99    None
# 7       Demonstração de Valor Adicionado          1            9    None
# 8              Balanço Patrimonial Ativo          2            2    None
# 9            Balanço Patrimonial Passivo          2            3    None
# 10             Demonstração do Resultado          2            4    None
# 11  Demonstração do Resultado Abrangente          2            5    None
# 12        Demonstração do Fluxo de Caixa          2           99    None
# 13      Demonstração de Valor Adicionado          2            9    None
# 14                 Composição do Capital       None         None    None
# 15                 Proventos em Dinheiro       None         None    None
# 16             Balanço Patrimonial Ativo          1            2    None
# 17           Balanço Patrimonial Passivo          1            3    None
# 18             Demonstração do Resultado          1            4    None
# 19  Demonstração do Resultado Abrangente          1            5    None
# 20        Demonstração do Fluxo de Caixa          1           99    None
# 21      Demonstração de Valor Adicionado          1            9    None
# 22             Balanço Patrimonial Ativo          2            2    None
# 23           Balanço Patrimonial Passivo          2            3    None
# 24             Demonstração do Resultado          2            4    None
# 25  Demonstração do Resultado Abrangente          2            5    None
# 26        Demonstração do Fluxo de Caixa          2           99    None
# 27      Demonstração de Valor Adicionado          2            9    None
#
#                    category  ... document_date     submission_date  \
# 0   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 1   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 2   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 3   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 4   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 5   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 6   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 7   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 8   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 9   Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 10  Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 11  Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 12  Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 13  Informações Trimestrais  ...    2024-09-30 2024-11-07 18:04:46
# 14  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 15  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 16  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 17  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 18  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 19  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 20  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 21  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 22  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 23  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 24  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 25  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 26  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
# 27  Informações Trimestrais  ...    2019-09-30 2019-10-23 19:12:51
#
#                        dri_name  \
# 0     DANIEL MARTINS DOS SANTOS
# 1     DANIEL MARTINS DOS SANTOS
# 2     DANIEL MARTINS DOS SANTOS
# 3     DANIEL MARTINS DOS SANTOS
# 4     DANIEL MARTINS DOS SANTOS
# 5     DANIEL MARTINS DOS SANTOS
# 6     DANIEL MARTINS DOS SANTOS
# 7     DANIEL MARTINS DOS SANTOS
# 8     DANIEL MARTINS DOS SANTOS
# 9     DANIEL MARTINS DOS SANTOS
# 10    DANIEL MARTINS DOS SANTOS
# 11    DANIEL MARTINS DOS SANTOS
# 12    DANIEL MARTINS DOS SANTOS
# 13    DANIEL MARTINS DOS SANTOS
# 14  Maurício Fernandes Teixeira
# 15  Maurício Fernandes Teixeira
# 16  Maurício Fernandes Teixeira
# 17  Maurício Fernandes Teixeira
# 18  Maurício Fernandes Teixeira
# 19  Maurício Fernandes Teixeira
# 20  Maurício Fernandes Teixeira
# 21  Maurício Fernandes Teixeira
# 22  Maurício Fernandes Teixeira
# 23  Maurício Fernandes Teixeira
# 24  Maurício Fernandes Teixeira
# 25  Maurício Fernandes Teixeira
# 26  Maurício Fernandes Teixeira
# 27  Maurício Fernandes Teixeira
#
#                                         auditor_name  \
# 0     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 1     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 2     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 3     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 4     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 5     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 6     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 7     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 8     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 9     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 10    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 11    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 12    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 13    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA
# 14  Deloitte Touche Tohmatsu Auditores Independentes
# 15  Deloitte Touche Tohmatsu Auditores Independentes
# 16  Deloitte Touche Tohmatsu Auditores Independentes
# 17  Deloitte Touche Tohmatsu Auditores Independentes
# 18  Deloitte Touche Tohmatsu Auditores Independentes
# 19  Deloitte Touche Tohmatsu Auditores Independentes
# 20  Deloitte Touche Tohmatsu Auditores Independentes
# 21  Deloitte Touche Tohmatsu Auditores Independentes
# 22  Deloitte Touche Tohmatsu Auditores Independentes
# 23  Deloitte Touche Tohmatsu Auditores Independentes
# 24  Deloitte Touche Tohmatsu Auditores Independentes
# 25  Deloitte Touche Tohmatsu Auditores Independentes
# 26  Deloitte Touche Tohmatsu Auditores Independentes
# 27  Deloitte Touche Tohmatsu Auditores Independentes
#
#       responsible_technician cancellation_reason category_version  \
# 0        Arthur Ramos Arruda                                   V1
# 1        Arthur Ramos Arruda                                   V1
# 2        Arthur Ramos Arruda                                   V1
# 3        Arthur Ramos Arruda                                   V1
# 4        Arthur Ramos Arruda                                   V1
# 5        Arthur Ramos Arruda                                   V1
# 6        Arthur Ramos Arruda                                   V1
# 7        Arthur Ramos Arruda                                   V1
# 8        Arthur Ramos Arruda                                   V1
# 9        Arthur Ramos Arruda                                   V1
# 10       Arthur Ramos Arruda                                   V1
# 11       Arthur Ramos Arruda                                   V1
# 12       Arthur Ramos Arruda                                   V1
# 13       Arthur Ramos Arruda                                   V1
# 14  Daniel de Carvalho Primo                                   V1
# 15  Daniel de Carvalho Primo                                   V1
# 16  Daniel de Carvalho Primo                                   V1
# 17  Daniel de Carvalho Primo                                   V1
# 18  Daniel de Carvalho Primo                                   V1
# 19  Daniel de Carvalho Primo                                   V1
# 20  Daniel de Carvalho Primo                                   V1
# 21  Daniel de Carvalho Primo                                   V1
# 22  Daniel de Carvalho Primo                                   V1
# 23  Daniel de Carvalho Primo                                   V1
# 24  Daniel de Carvalho Primo                                   V1
# 25  Daniel de Carvalho Primo                                   V1
# 26  Daniel de Carvalho Primo                                   V1
# 27  Daniel de Carvalho Primo                                   V1
#
#                    protocol_number  \
# 0   008133ITR300920240100142690-73
# 1   008133ITR300920240100142690-73
# 2   008133ITR300920240100142690-73
# 3   008133ITR300920240100142690-73
# 4   008133ITR300920240100142690-73
# 5   008133ITR300920240100142690-73
# 6   008133ITR300920240100142690-73
# 7   008133ITR300920240100142690-73
# 8   008133ITR300920240100142690-73
# 9   008133ITR300920240100142690-73
# 10  008133ITR300920240100142690-73
# 11  008133ITR300920240100142690-73
# 12  008133ITR300920240100142690-73
# 13  008133ITR300920240100142690-73
# 14  019739ITR300920190100088769-88
# 15  019739ITR300920190100088769-88
# 16  019739ITR300920190100088769-88
# 17  019739ITR300920190100088769-88
# 18  019739ITR300920190100088769-88
# 19  019739ITR300920190100088769-88
# 20  019739ITR300920190100088769-88
# 21  019739ITR300920190100088769-88
# 22  019739ITR300920190100088769-88
# 23  019739ITR300920190100088769-88
# 24  019739ITR300920190100088769-88
# 25  019739ITR300920190100088769-88
# 26  019739ITR300920190100088769-88
# 27  019739ITR300920190100088769-88
#
#                                            hash  \
# 0   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 1   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 2   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 3   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 4   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 5   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 6   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 7   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 8   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 9   nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 10  nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 11  nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 12  nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 13  nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 14   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 15   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 16   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 17   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 18   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 19   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 20   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 21   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 22   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 23   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 24   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 25   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 26   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# 27   I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
#
#                                              full_url
# 0   https://www.rad.cvm.gov.br/ENET/frmDadosCompos...
# 1   https://www.rad.cvm.gov.br/ENET/frmDadosProven...
# 2   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 3   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 4   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 5   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 6   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 7   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 8   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 9   https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 10  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 11  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 12  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 13  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 14  https://www.rad.cvm.gov.br/ENET/frmDadosCompos...
# 15  https://www.rad.cvm.gov.br/ENET/frmDadosProven...
# 16  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 17  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 18  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 19  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 20  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 21  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 22  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 23  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 24  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 25  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 26  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
# 27  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...
#
# [28 rows x 21 columns]

# %%
import requests
from lxml import html

# Iterate over each row in the DataFrame
results = []

for _, row in df.iterrows():
    # Step 1: Try accessing the `full_url` first
    try:
        response = requests.get(row["full_url"], headers=headers)
        if response.status_code == 200:
            if b"Por favor, acesse este conte\xc3\xbado pela p\xc3\xa1gina principal dos documentos" in response.content:
                # If the specific content is found, load the main URL and retry
                print(f'{row["hash"]} full_url not ok {row["full_url"]}')
                requests.get(row["main_url"], headers=headers)  # Open main_url for context
                print(f'{row["hash"]} main_url ok {row["main_url"]}')
                response = requests.get(row["full_url"], headers=headers)  # Retry full_url

                # Check for XPath in the retried response
                if response.status_code == 200:
                    tree = html.fromstring(response.content)
                    element = tree.xpath('//*[@id="TituloTabelaSemBorda"]')
                    if element:
                        results.append({"nsd": row["nsd"], "url_checked": row["full_url"], "status": "OK"})
                        print(f'{row["hash"]} full_url ok {row["full_url"]}')
                    else:
                        results.append({"nsd": row["nsd"], "url_checked": row["full_url"], "status": "NOT FOUND"})
                else:
                    results.append({"nsd": row["nsd"], "url_checked": row["full_url"], "status": f"Failed ({response.status_code})"})
        else:
            results.append({"nsd": row["nsd"], "url_checked": row["full_url"], "status": f"Failed ({response.status_code})"})
    except Exception as e:
        results.append({"nsd": row["nsd"], "url_checked": row["full_url"], "status": f"Error: {str(e)}"})

# Convert results to a DataFrame for easier analysis
results_df = pd.DataFrame(results)
# Out:
# nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk full_url not ok https://www.rad.cvm.gov.br/ENET/frmDadosProventoDinheiroITR.aspx?Informacao=None&Demonstracao=None&Periodo=0&Grupo=Dados+da+Empresa&Quadro=Proventos+em+Dinheiro&NomeTipoDocumento=DFP&Empresa=LOJAS%2520RENNER%2520S.A.&DataReferencia=2024-09-30&Versao=V1&CodTipoDocumento=4&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJkmain_url ok https://www.rad.cvm.gov.br/ENET/frmGerenciaPaginaFRE.aspx?NumeroSequencialDocumento=142690&CodigoTipoInstituicao=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 17
#      15 requests.get(row["main_url"], headers=headers)  # Open main_url for context
#      16 print(f'{row["hash"]}main_url ok {row["main_url"]}')
# ---> 17 response = requests.get(row["full_url"], headers=headers)  # Retry full_url
#      19 # Check for XPath in the retried response
#      20 if response.status_code == 200:
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     738     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     739     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742         sock=sock,
#     743         cert_reqs=self.cert_reqs,
#     744         ssl_version=self.ssl_version,
#     745         ssl_minimum_version=self.ssl_minimum_version,
#     746         ssl_maximum_version=self.ssl_maximum_version,
#     747         ca_certs=self.ca_certs,
#     748         ca_cert_dir=self.ca_cert_dir,
#     749         ca_cert_data=self.ca_cert_data,
#     750         cert_file=self.cert_file,
#     751         key_file=self.key_file,
#     752         key_password=self.key_password,
#     753         server_hostname=server_hostname_rm_dot,
#     754         ssl_context=self.ssl_context,
#     755         tls_in_tls=tls_in_tls,
#     756         assert_hostname=self.assert_hostname,
#     757         assert_fingerprint=self.assert_fingerprint,
#     758     )
#     759     self.sock = sock_and_verified.socket
#     761 # If an error occurs during connection/handshake we may need to release
#     762 # our lock so another connection can probe the origin.
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\connection.py:920, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     917     if is_ipaddress(normalized):
#     918         server_hostname = normalized
# --> 920 ssl_sock = ssl_wrap_socket(
#     921     sock=sock,
#     922     keyfile=key_file,
#     923     certfile=cert_file,
#     924     key_password=key_password,
#     925     ca_certs=ca_certs,
#     926     ca_cert_dir=ca_cert_dir,
#     927     ca_cert_data=ca_cert_data,
#     928     server_hostname=server_hostname,
#     929     ssl_context=context,
#     930     tls_in_tls=tls_in_tls,
#     931 )
#     933 try:
#     934     if assert_fingerprint:
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\util\ssl_.py:460, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456         context.load_cert_chain(certfile, keyfile, key_password)
#     458 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 460 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461 return ssl_sock
#
# File d:\Fausto Stangler\Documentos\Python\FLY\.venv\lib\site-packages\urllib3\util\ssl_.py:504, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     501     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     502     return SSLTransport(sock, ssl_context, server_hostname)
# --> 504 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
response.content
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n\r\n<html>\r\n<head><link href="App_Themes/CVM/Calendar/Skins/CVM/Calendar.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Calendar/Skins/CVM/RadTimePicker.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Calendario.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/ComboBox/CVM/Styles.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/ComboBox/Skins/CVM/Styles.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/EditarConteudo.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Entrada.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Erro.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Estrutura.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Ferramentas.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Formulario.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/FormularioReferencia.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Grid.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Input/Skins/CVM/styles.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Login.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Logout.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Menu.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Pesquisa.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/PopUp.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/TabStrip.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Tabstrip/Scripts/3_6_2/tabstrip.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Tabstrip/Scripts/3_6_2/vtabstrip.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Tabstrip/Skins/CBLC/styles.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Tabstrip/Skins/CVM/styles.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Topo.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/TrocaSenha.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Upload/Skins/CVM/RadUpload.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Upload/Skins/CVM/RadUploadProgressArea.css" type="text/css" rel="stylesheet" /><link href="App_Themes/CVM/Window/Skins/CVM/Window.css" type="text/css" rel="stylesheet" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><title>\r\n\tENET ITR  - Balan\xc3\xa7o Patrimonial Ativo / Passivo\r\n</title>\r\n    <script type="text/javascript" src="/ENET/ruxitagentjs_ICANQVfgqrux_10303241106123517.js" data-dtconfig="rid=RID_171418713|rpid=-285473758|domain=cvm.gov.br|reportUrl=/ENET/rb_3e3688fc-2b0e-4bc4-bbfb-2999b956e3bd|app=ca883f3beebf9526|featureHash=ICANQVfgqrux|msl=153600|srsr=20000|rdnt=1|uxrgce=1|cuc=wj11fgxl|srms=2,2,1,|mel=100000|expw=1|dpvc=1|lastModification=1734131275574|tp=500,50,0|agentUri=/ENET/ruxitagentjs_ICANQVfgqrux_10303241106123517.js"></script><link rel="Stylesheet" href="css//FormularioReferencia.css" type="text/css" />\r\n    <link rel="Stylesheet" href="jquery/ui/jquery-ui.css" />\r\n\r\n    <script type="text/javascript" async src="https://www.googletagmanager.com/gtag/js?id=UA-99990786-2"></script>\r\n        <script type="text/javascript">\r\n            window.dataLayer = window.dataLayer || [];\r\n            function gtag() { dataLayer.push(arguments); }\r\n            gtag(\'js\', new Date());\r\n            gtag(\'config\', \'UA-99990786-2\');\r\n\r\n            function openDados(evt, cityName) {\r\n\r\n                evt.preventDefault();\r\n                evt.stopPropagation();\r\n\r\n                var i, tabcontent, tablinks;\r\n                tabcontent = document.getElementsByClassName("tabcontent");\r\n                for (i = 0; i < tabcontent.length; i++) {\r\n                    tabcontent[i].styl ...

# %%
results_df
# Out:
#        nsd                                        url_checked status
# 0   142690  https://www.rad.cvm.gov.br/ENET/frmDadosCompos...     OK
# 1   142690  https://www.rad.cvm.gov.br/ENET/frmDadosProven...     OK
# 2   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 3   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 4   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 5   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 6   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 7   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 8   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 9   142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 10  142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 11  142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 12  142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 13  142690  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 14   88769  https://www.rad.cvm.gov.br/ENET/frmDadosCompos...     OK
# 15   88769  https://www.rad.cvm.gov.br/ENET/frmDadosProven...     OK
# 16   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 17   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 18   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 19   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 20   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 21   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 22   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 23   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 24   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 25   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 26   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK
# 27   88769  https://www.rad.cvm.gov.br/ENET/frmDemonstraca...     OK

# %% [markdown]
# ### Hash and Company and data

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from lxml import html
from urllib.parse import urlencode, urlparse, parse_qs
import re

# %%
# Headers for requests
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36",
    "Referer": "https://www.rad.cvm.gov.br/",
}

def get_soup(nsd):
    # Step 1: Generate and open `company_quarter_url`
    # company_quarter_url = f"https://www.rad.cvm.gov.br/ENET/frmGerenciaPaginaFRE.aspx?NumeroSequencialDocumento={nsd}&CodigoTipoInstituicao=1"
    nsd_url = f"https://www.rad.cvm.gov.br/ENET/frmNBC.aspx?NSD={nsd}"
    response = requests.get(nsd_url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
    return soup, nsd_url

def get_data(nsd_url):

    # Initialize a dictionary to store extracted data
    data = {}

    # Extract data from HTML elements
    try:
        # base info
        data["nsd"] = nsd
        data["url"] = nsd_url

        # 1. Extract company name
        data["company_name"] = soup.select_one("#lblNomeCompanhia").text.strip()

        # 2. Extract description category
        desc_text = soup.select_one("#lblDescricaoCategoria").text.strip()
        desc_split = desc_text.split(" - ")
        data["category"] = desc_split[0]
        data["category_date"] = datetime.strptime(desc_split[1], "%d/%m/%Y") if len(desc_split[1]) > 4 else datetime.strptime(f"31/12/{desc_split[1]}", "%d/%m/%Y")
        data["category_version"] = desc_split[2] if len(desc_split) > 2 else None

        # 3. Extract DRI details
        dri_text = soup.select_one("#lblNomeDRI").text.strip()
        dri_split = dri_text.split(" - (")
        data["dri_name"] = dri_split[0].strip()
        if len(dri_split) > 1:
            dri_info = dri_split[1].rstrip(")").split(" ")
            data["dri_fca"] = dri_info[0]
            data["dri_version"] = dri_info[1]

        # 4. Extract auditor details
        auditor_text = soup.select_one("#lblAuditor").text.strip()
        auditor_split = auditor_text.split(" - (")
        data["auditor_name"] = auditor_split[0]
        if len(auditor_split) > 1:
            auditor_info = auditor_split[1].rstrip(")").split(" ")
            data["auditor_fca"] = auditor_info[0]
            data["auditor_year"] = auditor_info[1]
            data["auditor_version"] = auditor_info[2]

        # 5. Extract responsible technician
        data["responsible_technician"] = soup.select_one("#lblResponsavelTecnico").text.strip()

        # 6. Extract protocol number
        data["protocol_number"] = soup.select_one("#lblProtocolo").text.strip()

        # 7. Extract document date
        doc_date = soup.select_one("#lblDataDocumento").text.strip()
        data["document_date"] = datetime.strptime(doc_date, "%d/%m/%Y")

        # 8. Extract submission date
        submission_date = soup.select_one("#lblDataEnvio").text.strip()
        data["submission_date"] = datetime.strptime(submission_date, "%d/%m/%Y %H:%M:%S")

        # 9. Extract cancellation reason
        data["cancellation_reason"] = soup.select_one("#lblMotivoCancelamentoReapresentacao").text.strip()

    except Exception as e:
        print(f"Error extracting page information: {str(e)}")

    # Extract embedded URL information from JavaScript
    try:
        script_content = soup.find("script", string=re.compile(r"window.frames\[0\]\.location="))
        if script_content:
            match = re.search(r"window\.frames\[0\]\.location=\'(.+?)\';", script_content.string)
            if match:
                embedded_url = match.group(1)
                parsed_url = urlparse(embedded_url)
                query_params = parse_qs(parsed_url.query)

                # Add the path to the data dictionary
                data["path"] = parsed_url.path

                # Flatten and add the query parameters to the data dictionary
                for key, value in query_params.items():
                    data[key] = value[0] if len(value) == 1 else value
    except Exception as e:
        print(f"Error extracting script information: {str(e)}")

    return data

def get_urls(data):
    urls = []
    base_url = data['url'].rsplit('/', 1)[0] + '/'


    urls.append(data["url"])

    # 1. frmDadosComposicaoCapitalITR.aspx
    urls.append(base_url + "frmDadosComposicaoCapitalITR.aspx?" + urlencode({
        "Grupo": "Dados da Empresa",
        "Quadro": "Composição do Capital", 
        "NomeTipoDocumento": data["NomeTipoDocumento"],
        "Empresa": data["Empresa"],
        "DataReferencia": data["DataReferencia"],
        "Versao": data["Versao"],
        "CodTipoDocumento": data["CodTipoDocumento"],
        "NumeroSequencialDocumento": data["NumeroSequencialDocumento"],
        "NumeroSequencialRegistroCvm": data["NumeroSequencialRegistroCvm"],
        "CodigoTipoInstituicao": data["CodigoTipoInstituicao"],
        "Hash": data["Hash"]
    }))

    # 2. frmDadosProventoDinheiroITR.aspx
    urls.append(base_url + "frmDadosProventoDinheiroITR.aspx?" + urlencode({
        "Grupo": "Dados da Empresa",
        "Quadro": "Proventos em Dinheiro", 
        "NomeTipoDocumento": data["NomeTipoDocumento"],
        "Empresa": data["Empresa"],
        "DataReferencia": data["DataReferencia"],
        "Versao": data["Versao"],
        "CodTipoDocumento": data["CodTipoDocumento"],
        "NumeroSequencialDocumento": data["NumeroSequencialDocumento"],
        "NumeroSequencialRegistroCvm": data["NumeroSequencialRegistroCvm"],
        "CodigoTipoInstituicao": data["CodigoTipoInstituicao"],
        "Hash": data["Hash"]
    }))

    # informa;'ao mappings
    informacao_mapping = {
        "1": "DFs Individuais",
        "2": "DFs Consolidadas"
    }

    # Demonstracao mappings
    demonstracao_mapping = {
        "2": "Balanço Patrimonial Ativo",
        "3": "Balanço Patrimonial Passivo",
        "4": "Demonstração do Resultado",
        "5": "Demonstração do Resultado Abrangente",
        "99": "Demonstração do Fluxo de Caixa",
        "9": "Demonstração de Valor Adicionado"
    }

    # Generate URLs for frmDemonstracaoFinanceiraITR.aspx with Informacao 1 and 2 mappings
    for informacao, grupo in informacao_mapping.items():
        for demonstracao, quadro in demonstracao_mapping.items():
            urls.append(base_url + "frmDemonstracaoFinanceiraITR.aspx?" + urlencode({
                "Informacao": informacao,
                "Demonstracao": demonstracao,
                "Periodo": "0",
                "Grupo": grupo,
                "Quadro": quadro,
                "NomeTipoDocumento": data["NomeTipoDocumento"],
                "Empresa": data["Empresa"],
                "DataReferencia": data["DataReferencia"],
                "Versao": data["Versao"],
                "CodTipoDocumento": data["CodTipoDocumento"],
                "NumeroSequencialDocumento": data["NumeroSequencialDocumento"],
                "NumeroSequencialRegistroCvm": data["NumeroSequencialRegistroCvm"],
                "CodigoTipoInstituicao": data["CodigoTipoInstituicao"],
                "Hash": data["Hash"]
            }))
    return urls

def get_info(data):
    info = {}
    urls = get_urls(data)
    # Process URLs and print corresponding actions
    for url in urls:
        if 'frmNBC' in url:
            print("Get NSD data from:", url)
        elif 'frmDadosComposicaoCapitalITR' in url:
            print("Get Composição Capital data from:", url)
        elif 'frmDemonstracaoFinanceiraITR' in url:
            response = requests.get(url, headers=headers)
            print(response, "Get Financial Data from:", url)
        
    return info
# Initialize results
results = []

# List of NSDs
nsds = ["88772", "142690", "88769"]

nsd_urls = {}

# Iterate over the NSDs list
for nsd in nsds:
    print(nsd)
    soup, nsd_url = get_soup(nsd)
    data = get_data(nsd_url)
    info = get_info(data)
    nsd_urls[nsd] = info
# Out:
# 88772
# Get NSD data from: https://www.rad.cvm.gov.br/ENET/frmNBC.aspx?NSD=88772
# Get Composição Capital data from: https://www.rad.cvm.gov.br/ENET/frmDadosComposicaoCapitalITR.aspx?Grupo=Dados+da+Empresa&Quadro=Composi%C3%A7%C3%A3o+do+Capital&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=2&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=3&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=4&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=5&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=99&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=9&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=2&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=3&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=4&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=5&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=99&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=9&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=EDP+S%C3%83O+PAULO+DISTRIBUI%C3%87%C3%83O+DE+ENERGIA+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88772&NumeroSequencialRegistroCvm=1445&CodigoTipoInstituicao=1&Hash=z5Ln26MHtKrCjLOZa8E9tf3cdnH5uUJjU1sn3Go
# 142690
# Get NSD data from: https://www.rad.cvm.gov.br/ENET/frmNBC.aspx?NSD=142690
# Get Composição Capital data from: https://www.rad.cvm.gov.br/ENET/frmDadosComposicaoCapitalITR.aspx?Grupo=Dados+da+Empresa&Quadro=Composi%C3%A7%C3%A3o+do+Capital&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=2&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=3&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=4&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=5&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=99&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=9&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=2&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=3&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=4&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=5&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=99&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=9&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=LOJAS+RENNER+S.A.&DataReferencia=2024-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=142690&NumeroSequencialRegistroCvm=2006&CodigoTipoInstituicao=1&Hash=nUd7OB5sA4epSMGTnHdHD6HOWRIpz3G3NhUZ9mCEXJk
# 88769
# Get NSD data from: https://www.rad.cvm.gov.br/ENET/frmNBC.aspx?NSD=88769
# Get Composição Capital data from: https://www.rad.cvm.gov.br/ENET/frmDadosComposicaoCapitalITR.aspx?Grupo=Dados+da+Empresa&Quadro=Composi%C3%A7%C3%A3o+do+Capital&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=2&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=3&Periodo=0&Grupo=DFs+Individuais&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=4&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=5&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=99&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=1&Demonstracao=9&Periodo=0&Grupo=DFs+Individuais&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=2&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Ativo&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=3&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Balan%C3%A7o+Patrimonial+Passivo&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=4&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=5&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Resultado+Abrangente&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=99&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+do+Fluxo+de+Caixa&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8
# <Response [200]> Get Financial Data from: https://www.rad.cvm.gov.br/ENET/frmDemonstracaoFinanceiraITR.aspx?Informacao=2&Demonstracao=9&Periodo=0&Grupo=DFs+Consolidadas&Quadro=Demonstra%C3%A7%C3%A3o+de+Valor+Adicionado&NomeTipoDocumento=ITR&Empresa=Localiza+Rent+a+Car+S.A.&DataReferencia=2019-09-30&Versao=1&CodTipoDocumento=3&NumeroSequencialDocumento=88769&NumeroSequencialRegistroCvm=1723&CodigoTipoInstituicao=1&Hash=I516d7fvoMh19MGLjjPdEbpLO1scsoi2Y9lczoqfI8

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Financial Ratios

# %%
def duplicate_dfs_types(df, source_type='Dados da Empresa', target_types=['DFs Consolidadas', 'DFs Individuais']):
    """
    Duplica condicionalmente as linhas de um tipo específico para outros tipos, 
    baseando-se na existência prévia desses tipos para a mesma empresa e quarter.
    
    Parâmetros:
    - df (pd.DataFrame): DataFrame original contendo os dados financeiros.
    - source_type (str): O tipo de linha que será duplicado. Padrão: 'Dados da Empresa'.
    - target_types (list of str): Lista dos tipos para os quais as linhas serão duplicadas.
                                   Padrão: ['DFs Consolidadas', 'DFs Individuais'].
    
    Retorna:
    - pd.DataFrame: DataFrame atualizado com as duplicações condicionais.
    """
    
    # Passo 1: Identificar combinações existentes de company_name e quarter para cada target_type
    existing_combinations = {}
    for target in target_types:
        existing_keys = df[df['type'] == target][['company_name', 'quarter']].drop_duplicates()
        existing_combinations[target] = existing_keys

    # Passo 2: Filtrar as linhas do source_type
    source_df = df[df['type'] == source_type].copy()
    
    # Passo 3: Para cada target_type, verificar onde duplicar
    duplicated_dfs = []
    for target in target_types:
        # Obter as combinações onde já existe o target_type
        target_keys = existing_combinations[target]
        
        # Realizar um merge para identificar quais linhas do source_df têm a combinação existente
        to_duplicate = source_df.merge(target_keys, on=['company_name', 'quarter'], how='inner', suffixes=('', '_target'))
        
        if not to_duplicate.empty:
            # Duplicar as linhas e alterar o type para o target_type
            duplicated = to_duplicate.copy()
            duplicated['type'] = target
            duplicated_dfs.append(duplicated)
            # print(f"Duplicando {len(duplicated)} linhas para o tipo '{target}'.")
        else:
            # print(f"Nenhuma duplicação necessária para o tipo '{target}'.")
            pass
    
    # Passo 4: Concatenar todas as duplicações
    if duplicated_dfs:
        duplicated_df = pd.concat(duplicated_dfs, ignore_index=True)
    else:
        duplicated_df = pd.DataFrame(columns=df.columns)
        # print("Nenhuma duplicação realizada.")
    
    # Passo 5: Remover as linhas originais do source_type
    df_filtered = df[df['type'] != source_type].copy()
    
    # Passo 6: Adicionar as duplicações ao DataFrame
    if not duplicated_df.empty:
        df_updated = pd.concat([df_filtered, duplicated_df], ignore_index=True)
    else:
        df_updated = df_filtered.copy()
    
    # Passo 7: Resetar o índice e ordenar o DataFrame (opcional)
    df_updated.reset_index(drop=True, inplace=True)
    
    # Passo 8: Ordenar o DataFrame
    df_updated = df_updated.sort_values(
        by=['sector', 'subsector', 'segment', 'company_name', 'quarter', 'version', 'type', 'account', 'description']
    ).reset_index(drop=True)
    
    return df_updated

# %%
def add_indicators(df, frame_name, indicator_list):
    """
    Calcula indicadores financeiros e os adiciona como novas linhas no DataFrame.

    Parâmetros:
    - df (pd.DataFrame): DataFrame original contendo os dados financeiros.
    - indicator_list (list of dict): Lista de dicionários com definições dos indicadores.

    Retorna:
    - pd.DataFrame: DataFrame atualizado com as novas linhas de indicadores.
    """
   # Função para realizar divisão segura
    def safe_division(numerator, denominator):
        with np.errstate(divide='ignore', invalid='ignore'):
            result = numerator / denominator
            result = result.replace([np.inf, -np.inf], np.nan)  # Substitui infinitos por NaN
            return result

    # Passo 1: Pivotar o DataFrame com contas como colunas e incluir 'quarter' no índice
    pivot_df = df.pivot_table(
        index=['company_name', 'type', 'quarter'],
        columns='account',
        values='value',
        aggfunc='sum',
        fill_value=0  # Substitui valores ausentes por 0
    ).reset_index()
    
    # print("Colunas do DataFrame Pivotado:", pivot_df.columns.tolist())
    
    # Passo 2: Calcular os Indicadores
    for indicator in indicator_list:
        column_name = indicator['description']
        column_account = indicator['account']
        try:
            # Aplicar a fórmula para calcular o indicador
            pivot_df[column_name] = indicator['formula'](pivot_df)
            # print(f"Indicador '{column_name}' calculado com sucesso.")
        except KeyError as e:
            print(f"'{column_account} - {column_name}': a conta {e} não existe")
            pivot_df[column_name] = np.nan  # Atribuir NaN se a coluna não existir
        except Exception as e:
            print(f"{column_name}': {e} Erro ao calcular o indicador '{column_name}': {e}")
            pivot_df[column_name] = np.nan  # Atribuir NaN em caso de erro

    # Passo 3: Criar Novas Linhas para os Indicadores
    new_rows = []
    
    for indicator in indicator_list:
        account = indicator['account']
        description = indicator['description']
        
        if description not in pivot_df.columns:
            print(f"Aviso: Indicador '{description}' não foi calculado e será ignorado.")
            continue
        
        # Extrair os valores calculados do indicador
        pivot_df['value'] = pivot_df[description]
        
        # Selecionar as colunas relevantes
        indicator_values = pivot_df[['company_name', 'type', 'quarter', 'value']].copy()
        indicator_values['account'] = account
        indicator_values['description'] = description
        
        # Atribuir 'frame' como 'Indicadores' para identificar facilmente as novas linhas
        indicator_values['frame'] = frame_name
        
        # Preencher as colunas faltantes com informações do DataFrame original
        # Selecionar combinações únicas de 'company_name', 'type' e 'quarter'
        metadata = df[['company_name', 'type', 'quarter', 'nsd', 'sector', 'subsector', 'segment', 'version']].drop_duplicates(subset=['company_name', 'type', 'quarter'], keep='first')
        
        # Mesclar com 'metadata' para preencher 'nsd', 'sector', etc.
        indicator_row = indicator_values.merge(metadata, on=['company_name', 'type', 'quarter'], how='left')
        
        # Reordenar as colunas para corresponder ao DataFrame original
        indicator_row = indicator_row[['nsd', 'sector', 'subsector', 'segment', 'company_name', 'quarter', 'version', 'type', 'frame', 'account', 'description', 'value']]
        
        # Adicionar à lista de novas linhas
        new_rows.append(indicator_row)
    
    # Combinar todas as novas linhas de indicadores
    if new_rows:
        new_rows_df = pd.concat(new_rows, ignore_index=True)
    else:
        new_rows_df = pd.DataFrame(columns=df.columns)
        # print("Nenhum indicador foi adicionado.")
    
    # Passo 4: Adicionar as Novas Linhas ao DataFrame Original
    updated_df = pd.concat([df, new_rows_df], ignore_index=True)
    
    # Passo 5: Tratamento Final dos Valores
    # Opcional: Preencher valores faltantes ou realizar outras limpezas
    # Exemplo: Substituir NaN por zero onde apropriado
    # updated_df['value'] = updated_df['value'].fillna(0)
    
    return updated_df

# %%
sector = 'COMUNICACOES'
db_file = f"..\data\{settings.db_filepath.split('.')[0]} {settings.statements_standard}.db"

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Fetch all table names excluding internal SQLite tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = cursor.fetchall()

df = pd.read_sql_query(f"SELECT * FROM {sector}", conn)
# df['account_description'] = df['account'] + ' - ' + df['description']
df['quarter'] = pd.to_datetime(df['quarter'])

# df = clean_dados_da_empresa(df)
df = duplicate_dfs_types(df)

# Store unique values
uv = {}
for col in df.columns:
    if col not in ['nsd', 'value']:
        uv[col] = sorted(df[col].unique().tolist())

df[['account', 'description']].drop_duplicates().to_csv('account-description.csv', index=False)

# %%
# Definition of indicator formulas
indicators_08 = [
    {
        'account': '08.01',
        'description': 'ROE Return On Equity',
        'formula': lambda df: df['03.11'] / df['02.03'] * 10000  # ROE = Net Profit / Shareholders' Equity * 100
    },
    {
        'account': '08.02',
        'description': 'Índice de Liquidez Corrente',
        'formula': lambda df: df['01.01'] / df['02.01']  # Current Ratio = Current Assets / Current Liabilities
    },
    # Add more indicators as needed
]

# %%
df = add_indicators(df, 'Indicadores Fundamentalistas', indicators_08)
# Store unique values
uvi = {}
for col in df.columns:
    if col not in ['nsd', 'value']:
        uvi[col] = sorted(df[col].unique().tolist())

# %%
mask  = df['company_name'] == uvi['company_name'][7]
mask &= df['type'] == uvi['type'][1]
mask &= df['account'] == '08.02'
# mask &= df2['quarter'] == '2020-12-31'
df[mask]

# %%
index_cols = [col for col in df2.columns if col not in ['quarter', 'value']]

# Verificar duplicatas
duplicatas = df2.duplicated(subset=index_cols + ['quarter'], keep=False)
num_duplicatas = duplicatas.sum()

if num_duplicatas > 0:
    print("Agregando duplicatas somando os valores.")
    df2_agregado = df2.groupby(index_cols + ['quarter'], as_index=False)['value'].sum()
    # df2_agregado = df2.groupby(index_cols + ['quarter'], as_index=False)['value'].mean() # opcionalmente calcular a média

else:
    df2_agregado = df2.copy()

# Pivotar o DataFrame
df_pivot = df2_agregado.pivot_table(
    index=index_cols,
    columns='quarter',
    values='value',
    aggfunc='first'  # 'first' assume que não há duplicatas após a agregação
).reset_index()

# # Obter uma lista dos quarters únicos, ordenados de forma decrescente
# sorted_quarters = sorted(df_pivot.columns[ len(index_cols): ], reverse=True)

# # Reordenar as colunas: primeiro os índices, depois os quarters em ordem decrescente
# df_pivot = df_pivot[index_cols + sorted_quarters]

# # Opcional: formatar os nomes das colunas de quarter para strings legíveis
# df_pivot.columns = list(index_cols) + [q.strftime('%Y-%m-%d') for q in sorted_quarters]

df_pivot.fillna(0, inplace=True)
df_pivot

# %%
df_pivot.iloc[0:1,]

# %% [markdown]
# ### Plots

# %%
sector = 'COMUNICACOES'
db_file = f"..\data\{settings.db_filepath.split('.')[0]} {settings.statements_standard}.db"

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Fetch all table names excluding internal SQLite tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = cursor.fetchall()

df = pd.read_sql_query(f"SELECT * FROM {sector}", conn)
# df['account_description'] = df['account'] + ' - ' + df['description']
df['quarter'] = pd.to_datetime(df['quarter'])

# %%
# Store unique values
uv = {}
for col in df.columns:
    if col not in ['nsd', 'value']:
        uv[col] = sorted(df[col].unique().tolist())
uv
# Out:
# {'sector': ['COMUNICACOES'],
#  'subsector': ['MIDIA', 'TELECOMUNICACOES'],
#  'segment': ['PUBLICIDADE E PROPAGANDA', 'TELECOMUNICACOES'],
#  'company_name': ['ALGAR TELECOM SA',
#   'BRISANET PARTICIPACOES SA',
#   'DESKTOP SA',
#   'ELETROMIDIA SA',
#   'GIGA MAIS FIBRA TELECOMUNICACOES SA',
#   'OI SA',
#   'TELEC BRASILEIRAS SA TELEBRAS',
#   'TELEFONICA BRASIL SA',
#   'TIM SA',
#   'UNIFIQUE TELECOMUNICACOES SA'],
#  'quarter': [Timestamp('2010-12-31 00:00:00'),
#   Timestamp('2011-03-31 00:00:00'),
#   Timestamp('2011-06-30 00:00:00'),
#   Timestamp('2011-09-30 00:00:00'),
#   Timestamp('2011-12-31 00:00:00'),
#   Timestamp('2012-03-31 00:00:00'),
#   Timestamp('2012-06-30 00:00:00'),
#   Timestamp('2012-09-30 00:00:00'),
#   Timestamp('2012-12-31 00:00:00'),
#   Timestamp('2013-03-31 00:00:00'),
#   Timestamp('2013-06-30 00:00:00'),
#   Timestamp('2013-09-30 00:00:00'),
#   Timestamp('2013-12-31 00:00:00'),
#   Timestamp('2014-03-31 00:00:00'),
#   Timestamp('2014-06-30 00:00:00'),
#   Timestamp('2014-09-30 00:00:00'),
#   Timestamp('2014-12-31 00:00:00'),
#   Timestamp('2015-03-31 00:00:00'),
#   Timestamp('2015-06-30 00:00:00'),
#   Timestamp('2015-09-30 00:00:00'),
#   Timestamp('2015-12-31 00:00:00'),
#   Timestamp('2016-03-31 00:00:00'),
#   Timestamp('2016-06-30 00:00:00'),
#   Timestamp('2016-09-30 00:00:00'),
#   Timestamp('2016-12-31 00:00:00'),
#   Timestamp('2017-03-31 00:00:00'),
#   Timestamp('2017-06-30 00:00:00'),
#   Timestamp('2017-09-30 00:00:00'),
#   Timestamp('2017-12-31 00:00:00'),
#   Timestamp('2018-03-31 00:00:00'),
#   Timestamp('2018-06-30 00:00:00'),
#   Timestamp('2018-09-30 00:00:00'),
#   Timestamp('2018-12-31 00:00:00'),
#   Timestamp('2019-03-31 00:00:00'),
#   Timestamp('2019-06-30 00:00:00'),
#   Timestamp('2019-09-30 00:00:00'),
#   Timestamp('2019-12-31 00:00:00'),
#   Timestamp('2020-03-31 00:00:00'),
#   Timestamp('2020-06-30 00:00:00'),
#   Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-12-31 00:00:00'),
#   Timestamp('2021-03-31 00:00:00'),
#   Timestamp('2021-06-30 00:00:00'),
#   Timestamp('2021-09-30 00:00:00'),
#   Timestamp('2021-12-31 00:00:00'),
#   Timestamp('2022-03-31 00:00:00'),
#   Timestamp('2022-06-30 00:00:00'),
#   Timestamp('2022-09-30 00:00:00'),
#   Timestamp('2022-12-31 00:00:00'),
#   Timestamp('2023-03-31 00:00:00'),
#   Timestamp('2023-06-30 00:00:00'),
#   Timestamp('2023-09-30 00:00:00'),
#   Timestamp('2023-12-31 00:00:00'),
#   Timestamp('2024-03-31 00:00:00'),
#   Timestamp('2024-06-30 00:00:00')],
#  'version': ['1', '2', '3', '4'],
#  'type': ['DFs Consolidadas', 'DFs Individuais', 'Dados da Empresa'],
#  'frame': ['Balanço Patrimonial Ativo',
#   'Balanço Patrimonial Passivo',
#   'Composição do Capital',
#   'Demonstração de Valor Adicionado',
#   'Demonstração do Fluxo de Caixa',
#   'Demonstração do Resultado'],
#  'account': ['00.01.01',
#   '00.01.02',
#   '00.02.01',
#   '00.02.02',
#   '01',
#   '01.01',
#   '01.01.01',
#   '01.01.01.01',
#   '01.01.01.02',
#   '01.01.02',
#   '01.01.02.01',
#   '01.01.02.02',
#   '01.01.03',
#   '01.01.03.01',
#   '01.01.03.01.01',
#   '01.01.03.01.02',
#   '01.01.03.01.03',
#   '01.01.03.02',
#   '01.01.04',
#   '01.01.04.01',
#   '01.01.04.02',
#   '01.01.04.03',
#   '01.01.05',
#   '01.01.06',
#   '01.01.07',
#   '01.01.09',
#   '01.02',
#   '01.02.01',
#   '01.02.01.02',
#   '01.02.01.03',
#   '01.02.01.04',
#   '01.02.01.05',
#   '01.02.01.06',
#   '01.02.01.07',
#   '01.02.01.08',
#   '01.02.01.09',
#   '01.02.02',
#   '01.02.02.01',
#   '01.02.02.01.01',
#   '01.02.02.01.02',
#   '01.02.02.01.03',
#   '01.02.02.02',
#   '01.02.03',
#   '01.02.03.01',
#   '01.02.03.02',
#   '01.02.04',
#   '01.02.04.01',
#   '01.02.04.01.01',
#   '01.02.04.01.02',
#   '01.02.04.01.03',
#   '01.02.04.02',
#   '01.02.04.02.01',
#   '02',
#   '02.01',
#   '02.01.01.01',
#   '02.01.01.02',
#   '02.01.02',
#   '02.01.02.01',
#   '02.01.02.02',
#   '02.01.03',
#   '02.01.03.01',
#   '02.01.03.01.01',
#   '02.01.03.01.02',
#   '02.01.03.01.03',
#   '02.01.03.02',
#   '02.01.03.03',
#   '02.01.04',
#   '02.01.04.01',
#   '02.01.04.01.01',
#   '02.01.04.01.02',
#   '02.01.04.02',
#   '02.01.04.03',
#   '02.01.05',
#   '02.01.05.01',
#   '02.01.05.01.01',
#   '02.01.05.01.03',
#   '02.01.05.01.04',
#   '02.01.05.02',
#   '02.01.05.02.01',
#   '02.01.05.02.02',
#   '02.01.05.02.03',
#   '02.01.05.02.04',
#   '02.01.05.02.09',
#   '02.01.06',
#   '02.01.06.01',
#   '02.01.06.01.01',
#   '02.01.06.01.02',
#   '02.01.06.01.03',
#   '02.01.06.01.04',
#   '02.01.06.02',
#   '02.01.06.02.01',
#   '02.01.06.02.02',
#   '02.01.06.02.03',
#   '02.02',
#   '02.02.01',
#   '02.02.01.01',
#   '02.02.01.01.01',
#   '02.02.01.01.02',
#   '02.02.01.02',
#   '02.02.01.03',
#   '02.02.02',
#   '02.02.02.01.04',
#   '02.02.03',
#   '02.02.04',
#   '02.02.04.01',
#   '02.03',
#   '02.03.01',
#   '02.03.01.01',
#   '02.03.01.02',
#   '02.03.02',
#   '02.03.02.01',
#   '02.03.02.02',
#   '02.03.02.09',
#   '02.03.03',
#   '02.03.04',
#   '02.03.04.01',
#   '02.03.04.02',
#   '02.03.04.03',
#   '02.03.04.09',
#   '02.03.05',
#   '02.03.06',
#   '02.03.06.01',
#   '02.03.06.02',
#   '02.03.06.09',
#   '02.03.07',
#   '02.03.08',
#   '02.03.09',
#   '03.01',
#   '03.02',
#   '03.03',
#   '03.04',
#   '03.04.01',
#   '03.04.01.01',
#   '03.05',
#   '03.06',
#   '03.07',
#   '03.08',
#   '03.11',
#   '03.11.01',
#   '03.11.02',
#   '06.01',
#   '06.02',
#   '06.03',
#   '07.01',
#   '07.01.01',
#   '07.01.02',
#   '07.01.03',
#   '07.01.04',
#   '07.02',
#   '07.02.01',
#   '07.02.02',
#   '07.02.03',
#   '07.02.04',
#   '07.03',
#   '07.04',
#   '07.04.01',
#   '07.04.02',
#   '07.05',
#   '07.06',
#   '07.06.01',
#   '07.06.02',
#   '07.06.03',
#   '07.06.03.01',
#   '07.06.03.02',
#   '07.07',
#   '07.08',
#   '07.08.01',
#   '07.08.01.01',
#   '07.08.01.02',
#   '07.08.01.03',
#   '07.08.01.04',
#   '07.08.02',
#   '07.08.02.01',
#   '07.08.02.02',
#   '07.08.02.03',
#   '07.08.03',
#   '07.08.03.01',
#   '07.08.03.02',
#   '07.08.03.03',
#   '07.08.04',
#   '07.08.04.01',
#   '07.08.04.02',
#   '07.08.04.03',
#   '07.08.04.04',
#   '07.08.05.01',
#   '07.08.05.02',
#   '07.08.05.03',
#   '07.08.05.04',
#   '07.08.05.09'],
#  'description': ['Ajustes Acumulados de Conversão',
#   'Ajustes Patrimoniais',
#   'Ajustes de Avaliação Patrimonial',
#   'Aluguéis',
#   'Aplicações Financeiras de Curto Prazo',
#   'Aplicações Líquidas de Curto Prazo',
#   'Aplicações a Valor Justo de Curto Prazo',
#   'Aplicações a Valor Justo de Longo Prazo',
#   'Aplicações ao Custo Amortizado de Curto Prazo',
#   'Ativo Circulante de Curto Prazo',
#   'Ativo Não Circulante de Longo Prazo',
#   'Ativo Realizável a Longo Prazo',
#   'Ativo Total',
#   'Ativos Biológicos de Curto Prazo',
#   'Ativos Biológicos de Longo Prazo',
#   'Atribuído a Sócios Não Controladores',
#   'Atribuído a Sócios da Empresa Controladora',
#   'Ações ON Ordinárias',
#   'Ações PN Preferenciais',
#   'Ações, Remuneração e Opções',
#   'Benefícios',
#   'Caixa de Financiamento',
#   'Caixa de Investimento',
#   'Caixa de Operações (Operacional)',
#   'Caixa e Bancos de Curto Prazo',
#   'Caixa e Equivalentes de Caixa de Curto Prazo',
#   'Capital Social',
#   'Capital Social Realizado',
#   'Carteira de Clientes',
#   'Clientes',
#   'Contas a Receber de Curto Prazo',
#   'Contas a Receber de Longo Prazo',
#   'Contas de Clientes de Curto Prazo',
#   'Créditos com Partes Relacionadas de Longo Prazo',
#   'Créditos de Liquidação Duvidosa',
#   'Custo dos Bens e/ou Serviços Vendidos',
#   'Custos Prods., Mercs. e Servs. Vendidos',
#   'Debêntures',
#   'Depreciação, Amortização e Exaustão',
#   'Derivativos e Participações',
#   'Despesas Antecipadas de Curto Prazo',
#   'Despesas Antecipadas de Longo Prazo',
#   'Despesas Comerciais',
#   'Despesas Operacionais',
#   'Despesas/Receitas Operacionais',
#   'Direito de Uso em Arrendamento',
#   'Distribuição do Valor Adicionado',
#   'Dividendos',
#   'Dividendos e Ações',
#   'Dividendos e Ações em Tesouraria',
#   'Débitos com Coligadas',
#   'Débitos com Controladores',
#   'Débitos com Outras Partes Relacionadas',
#   'Em Moeda Estrangeira',
#   'Em Moeda Nacional',
#   'Em Tesouraria Ações ON Ordinárias',
#   'Em Tesouraria Ações PN Preferenciais',
#   'Empréstimos e Financiamentos',
#   'Empréstimos e Financiamentos de Curto Prazo',
#   'Empréstimos e Financiamentos de Longo Prazo',
#   'Estaduais',
#   'Estoques de Curto Prazo',
#   'Estoques de Longo Prazo',
#   'Estoques de Material de Consumo de Curto Prazo',
#   'Estoques de Material para Revenda de Curto Prazo',
#   'Estoques de Outros Itens de Curto Prazo',
#   'F.G.T.S.',
#   'Federais',
#   'Financiamento por Arrendamento Financeiro',
#   'Fornecedores Estrangeiros',
#   'Fornecedores Nacionais',
#   'Fornecedores de Curto Prazo',
#   'Gastos na emissão de ações',
#   'Goodwill',
#   'Imobilizado',
#   'Imobilizado em Operação',
#   'Imposto de Renda e Contribuição Social Diferidos',
#   'Imposto de Renda e Contribuição Social a Pagar',
#   'Imposto de Renda e Contribuição Social sobre o Lucro',
#   'Impostos, Taxas e Contribuições',
#   'Insumos Adquiridos de Terceiros',
#   'Intangíveis',
#   'Intangível',
#   'Investimento Social',
#   'Investimentos',
#   'Juros',
#   'Juros sobre o Capital Próprio',
#   'Lucro do Período',
#   'Lucros Retidos',
#   'Lucros Retidos / Prejuízo do Período',
#   'Lucros/Prejuízos Acumulados',
#   'Marcas e Patentes',
#   'Materiais, Energia, Servs. de Terceiros e Outros',
#   'Municipais',
#   'Obrigações Fiscais Estaduais',
#   'Obrigações Fiscais Federais',
#   'Obrigações Fiscais Municipais',
#   'Obrigações Fiscais de Curto Prazo',
#   'Obrigações Sociais',
#   'Obrigações Trabalhistas',
#   'Obrigações Tributárias e Autorizações',
#   'Outras',
#   'Outras Contas de Curto Prazo',
#   'Outras Obrigações Fiscais Federais',
#   'Outras Obrigações de Curto Prazo',
#   'Outras Provisões',
#   'Outras Receitas',
#   'Outros',
#   'Outros Ativos Circulantes de Curto Prazo',
#   'Outros Ativos Circulantes de Longo Prazo',
#   'Outros Resultados Abrangentes',
#   'Part. Não Controladores nos Lucros Retidos',
#   'Participação Minoritária',
#   'Participação dos Acionistas Não Controladores',
#   'Participações Societárias',
#   'Participações em Coligadas',
#   'Participações em Controladas',
#   'Passivo Circulante de Curto Prazo',
#   'Passivo Não Circulante de Longo Prazo',
#   'Passivo Total',
#   'Passivos com Partes Relacionadas',
#   'Passivos com Partes Relacionadas de Longo Prazo',
#   'Patrimônio Líquido',
#   'Perda/Recuperação de Valores Ativos',
#   'Perdas e Aquisições com Não Controladores',
#   'Pessoal',
#   'Propriedades para Investimento',
#   'Provisão/Reversão de Créds. Liquidação Duvidosa',
#   'Provisões Cíveis',
#   'Provisões Fiscais',
#   'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis',
#   'Provisões Judiciais',
#   'Provisões Previdenciárias e Trabalhistas',
#   'Provisões de Curto Prazo',
#   'Provisões de Longo Prazo',
#   'Provisões para Benefícios a Empregados',
#   'Provisões para Garantias',
#   'Provisões para Passivos Ambientais e de Desativação',
#   'Provisões para Reestruturação',
#   'Provisões trabalhistas e cíveis, líquidas',
#   'Receita de Venda de Bens e/ou Serviços',
#   'Receitas',
#   'Receitas Financeiras',
#   'Receitas refs. à Construção de Ativos Próprios',
#   'Remuneração Direta',
#   'Remuneração de Capitais Próprios',
#   'Remuneração de Capitais de Terceiros',
#   'Reservas Legais e Estatutárias',
#   'Reservas de Capital',
#   'Reservas de Lucros',
#   'Reservas de Reavaliação',
#   'Resultado Antes do Resultado Financeiro e dos Tributos',
#   'Resultado Antes dos Tributos sobre o Lucro',
#   'Resultado Bruto',
#   'Resultado Financeiro',
#   'Resultado de Equivalência Patrimonial',
#   'Retenção de Lucros e Incentivos Fiscais',
#   'Retenções',
#   'Softwares',
#   'Telecomunicações e Consignações',
#   'Tributos Parcelados',
#   'Tributos a Recuperar de Curto Prazo',
#   'Tributos a Recuperar de Longo Prazo',
#   'Valor Adicionado Bruto',
#   'Valor Adicionado Líquido Produzido',
#   'Valor Adicionado Total a Distribuir',
#   'Vendas de Mercadorias, Produtos e Serviços',
#   'Vlr Adicionado Recebido em Transferência',
#   'Ágio e Reserva Especial']}

# %%
def plot_series(company_name, account, start_date=None, end_date=None, window=4, std_dev=2, normalize=True):
    """
    Plot a time series of a financial metric for a given company, with Bollinger Bands and custom blue color scheme.
    
    Args:
    - company_name: Name of the company.
    - account: The financial account to be plotted.
    - start_date: Start date for filtering the data (optional).
    - end_date: End date for filtering the data (optional).
    - window: The window size for the moving average (default is 4).
    - std_dev: The number of standard deviations for the Bollinger Bands (default is 2).
    """
    # Define blue color scheme
    color_blue = {
        'main': 'blue',                
        'mma': 'lightblue',            
        'bands': 'lightblue',          
        'fill': 'rgba(173, 216, 230, 0.2)',  
        'extra_bands': 'lightgray',    
        'extra_fill': 'rgba(200, 200, 200, 0.2)'  
    }

    # Try 'DFs Consolidadas' first
    if (df['type'] == 'DFs Consolidadas').any():
        df_type = 'DFs Consolidadas'
    else:
        df_type = 'DFs Individuais'

    # Filter data
    data = df[
        (df['company_name'] == company_name) & 
        (df['account'] == account) & 
        (df['type'] == df_type)
    ]

    # Apply date filters if provided
    if start_date:
        data = data[data['quarter'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['quarter'] <= pd.to_datetime(end_date)]

    if data.empty:
        print("No data available for the given filters, check parameters.")
        return

    if normalize == True:
        # Drop the first row if its value is zero
        if data['value'].iloc[0] == 0:
            data = data.iloc[1:].copy()

        # Get the first non-zero value
        first_non_zero = data['value'].iloc[0]

        # Normalize the values by dividing by the first non-zero value
        data['value'] = data['value'] / first_non_zero

        # Scale the values so that the maximum is 100
        max_value = data['value'].max()
        data['value'] = (data['value'] / max_value) * 100

    # Sort data by date
    data = data.sort_values('quarter')

    # Calculate the moving average (Middle Band)
    data['mma'] = data['value'].rolling(window=window).mean()

    # Calculate the rolling standard deviation
    data['std_dev'] = data['value'].rolling(window=window).std()

    # Calculate upper and lower Bollinger Bands with std_dev multiplier
    data['upper_band'] = data['mma'] + std_dev * data['std_dev']
    data['lower_band'] = data['mma'] - std_dev * data['std_dev']

    # Calculate extra upper and lower bands using std_dev * 1.5
    extra_std_dev = std_dev * 1.5
    data['upper_band_extra'] = data['mma'] + extra_std_dev * data['std_dev']
    data['lower_band_extra'] = data['mma'] - extra_std_dev * data['std_dev']

    # Set description to the first non-null description value in the filtered data
    description = data['description'].dropna().iloc[0] if 'description' in data.columns and not data['description'].isna().all() else account

    # Create line plot with original values
    fig = px.line(
        data,
        x='quarter',
        y='value',
        title=f'{account} - {description} with Bollinger Bands for {company_name} ({df_type})',
        labels={'quarter': 'Quarter', 'value': description}, 
        template='plotly_white'  
    )
    
    # Add main line for the data
    fig.update_traces(line=dict(color=color_blue['main']), name='Original Data', showlegend=False)

    # Add moving average (MMA) as a dashed light blue line
    fig.add_scatter(
        x=data['quarter'],
        y=data['mma'],
        mode='lines',
        name=f'Middle Band (window={window})',
        line=dict(color=color_blue['mma'], dash='dash'),
        showlegend=False
    )

    # Add upper and lower Bollinger Bands (std_dev * 2) and group them
    fig.add_scatter(
        x=data['quarter'],
        y=data['upper_band'],
        mode='lines',
        name='Upper Band (std_dev * 2)',
        line=dict(dash='solid', color=color_blue['bands']),
        legendgroup='Bands (std_dev * 2)',
        showlegend=False
    )

    fig.add_scatter(
        x=data['quarter'],
        y=data['lower_band'],
        mode='lines',
        name='Lower Band (std_dev * 2)',
        line=dict(dash='solid', color=color_blue['bands']),
        legendgroup='Bands (std_dev * 2)',
        showlegend=False
    )

    # Fill the area between the upper and lower bands (std_dev * 2)
    fig.add_scatter(
        x=data['quarter'],
        y=data['upper_band'],
        fill=None,  
        mode='lines',
        name='Upper Band Fill (std_dev * 2)',
        line=dict(color='rgba(0,0,0,0)'),  
        showlegend=False,
        legendgroup='Bands (std_dev * 2)',
    )

    fig.add_scatter(
        x=data['quarter'],
        y=data['lower_band'],
        fill='tonexty',  
        mode='lines',
        name='Lower Band Fill (std_dev * 2)',
        line=dict(color='rgba(0,0,0,0)'),  
        fillcolor=color_blue['fill'],  
        showlegend=False,
        legendgroup='Bands (std_dev * 2)',
    )

    # Add extra upper and lower Bollinger Bands (std_dev * 1.5) and group them
    fig.add_scatter(
        x=data['quarter'],
        y=data['upper_band_extra'],
        mode='lines',
        name='Upper Band (std_dev * 1.5)',
        line=dict(dash='dot', color=color_blue['extra_bands']),
        legendgroup='Bands (std_dev * 1.5)',
        showlegend=False
    )

    fig.add_scatter(
        x=data['quarter'],
        y=data['lower_band_extra'],
        mode='lines',
        name='Lower Band (std_dev * 1.5)',
        line=dict(dash='dot', color=color_blue['extra_bands']),
        legendgroup='Bands (std_dev * 1.5)',
        showlegend=False
    )

    # Fill the area between the extra upper and lower bands (std_dev * 1.5)
    fig.add_scatter(
        x=data['quarter'],
        y=data['upper_band_extra'],
        fill=None,  
        mode='lines',
        name='Upper Band Extra Fill (std_dev * 1.5)',
        line=dict(color='rgba(0,0,0,0)'),  
        showlegend=False,
        legendgroup='Bands (std_dev * 1.5)',
    )

    fig.add_scatter(
        x=data['quarter'],
        y=data['lower_band_extra'],
        fill='tonexty',  
        mode='lines',
        name='Lower Band Extra Fill (std_dev * 1.5)',
        line=dict(color='rgba(0,0,0,0)'),  
        fillcolor=color_blue['extra_fill'],  
        showlegend=False,
        legendgroup='Bands (std_dev * 1.5)',
    )

    # Update layout
    fig.update_layout(xaxis_title='Quarter', yaxis_title=description)
    
    fig.show()

    return data

# %%
data = plot_series(
    company_name=uv['company_name'][7],  # Change to your desired company
    account='01.01',
    # start_date='2015-01-01',
    # end_date='2023-06-30', 
    window=4, 
    normalize=False
)

# %%
def plot_time_series(company_name, accounts, start_date=None, end_date=None, plot_type="stacked"):
    """
    Plot a stacked, overlapping, line-only, 100% stacked, or normalized stacked area chart of financial metrics for multiple accounts of a given company.
    
    Args:
    - company_name: Name of the company.
    - accounts: List of financial accounts to be plotted.
    - start_date: Start date for filtering the data (optional).
    - end_date: End date for filtering the data (optional).
    - plot_type: Determines the type of plot: "stacked", "overlapping", "lines", "100_stacked", or "normalized_stacked".
    """
    # Filter and combine data for all accounts
    filtered_data = pd.DataFrame()
    
    for account in accounts:
        # Try 'DFs Consolidadas' first
        if (df['type'] == 'DFs Consolidadas').any():
            df_type = 'DFs Consolidadas'
        else:
            df_type = 'DFs Individuais'

        # Filter data for the current account
        data = df[
            (df['company_name'] == company_name) & 
            (df['account'] == account) & 
            (df['type'] == df_type)
        ]
        
        # Apply date filters if provided
        if start_date:
            data = data[data['quarter'] >= pd.to_datetime(start_date)]
        if end_date:
            data = data[data['quarter'] <= pd.to_datetime(end_date)]

        if data.empty:
            print(f"No data available for account {account}. Skipping.")
            continue

        # Apply normalization only when plot_type is "normalized_stacked"
        if plot_type == "normalized_stacked":
            # Drop the first row if its value is zero
            if data['value'].iloc[0] == 0:
                data = data.iloc[1:].copy()

            # Get the first non-zero value and normalize all data by that value
            first_non_zero_value = data['value'][data['value'] != 0].iloc[0]

            # Normalize to ensure the first non-zero value is 1
            data.loc[:, 'value'] = data['value'] / first_non_zero_value

        # Sort data by date
        data = data.sort_values('quarter')
        
        # Add the account as a column for identifying each account
        data['account'] = account

        # Append to the cumulative data
        filtered_data = pd.concat([filtered_data, data])

    if filtered_data.empty:
        print("No data available for the given filters, check parameters.")
        return
    
    # Determine the Y-axis label
    y_axis_title = 'Value'
    
    # Plot logic for different plot types
    if plot_type == "stacked":
        # Stacked area plot with raw values
        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    elif plot_type == "overlapping":
        # Overlapping area plot (using filled line plots to avoid stacking)
        fig = px.line(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Overlapping Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )

        # Add filled areas to create the overlapping effect
        for account in accounts:
            account_data = filtered_data[filtered_data['account'] == account]
            fig.add_scatter(
                x=account_data['quarter'],
                y=account_data['value'],
                mode='lines',
                line=dict(width=0.5),
                fill='tozeroy',
                name=account,
                legendgroup=account,  # Group line and area under the same legend
                showlegend=False  # Hide the second entry for the filled area
            )

    elif plot_type == "lines":
        # Line-only plot with no filling
        fig = px.line(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Line-Only Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )

    elif plot_type == "100_stacked":
        # 100% stacked area plot (scaled to show percentages)
        filtered_data['total_per_quarter'] = filtered_data.groupby('quarter')['value'].transform('sum')
        filtered_data['value'] = (filtered_data['value'] / filtered_data['total_per_quarter']) * 100
        y_axis_title = 'Percentage Contribution (%)'
        
        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'100% Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    elif plot_type == "normalized_stacked":
        # Normalized stacked area plot (no percentage, just normalized values for each account)
        y_axis_title = 'Normalized Value'

        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Normalized Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    # Update layout
    fig.update_layout(xaxis_title='Quarter', yaxis_title=y_axis_title, showlegend=True)
    
    fig.show()

    return filtered_data

# %%
#     - plot_type: Determines the type of plot: "stacked", "lines", "overlapping", "100_stacked", or "normalized_stacked".
# Example usage: Line-only plot
data = plot_time_series(
    company_name=uv['company_name'][7],
    accounts=['01.01.01', '01.01.02', '01.01.03', '01.01.04', ],
    plot_type="stacked",  # Line-only plot
    start_date='2013-12-31',
)

# Example usage: Line-only plot
data = plot_time_series(
    company_name=uv['company_name'][7],
    accounts=['01.01.01', '01.01.02', '01.01.03', '01.01.04', ],
    plot_type="100_stacked",  # Line-only plot
    start_date='2013-12-31',
)

# %%
def plot_time_series(company_name, accounts, start_date=None, end_date=None, plot_type="stacked"):
    """
    Plot a stacked, overlapping, line-only, 100% stacked, or normalized stacked area chart of financial metrics for multiple accounts of a given company.
    
    Args:
    - company_name: Name of the company.
    - accounts: List of financial accounts to be plotted.
    - start_date: Start date for filtering the data (optional).
    - end_date: End date for filtering the data (optional).
    - plot_type: Determines the type of plot: "stacked", "overlapping", "lines", "100_stacked", or "normalized_stacked".
    """
    # Filter and combine data for all accounts
    filtered_data = pd.DataFrame()
    
    for account in accounts:
        # Try 'DFs Consolidadas' first
        if (df['type'] == 'DFs Consolidadas').any():
            df_type = 'DFs Consolidadas'
        else:
            df_type = 'DFs Individuais'

        # Filter data for the current account
        data = df[
            (df['company_name'] == company_name) & 
            (df['account'] == account) & 
            (df['type'] == df_type)
        ]
        
        # Apply date filters if provided
        if start_date:
            data = data[data['quarter'] >= pd.to_datetime(start_date)]
        if end_date:
            data = data[data['quarter'] <= pd.to_datetime(end_date)]

        if data.empty:
            print(f"No data available for account {account}. Skipping.")
            continue

        # Apply normalization only when plot_type is "normalized_stacked"
        if plot_type == "normalized_stacked":
            # Drop the first row if its value is zero
            if data['value'].iloc[0] == 0:
                data = data.iloc[1:].copy()

            # Get the first non-zero value and normalize all data by that value
            first_non_zero_value = data['value'][data['value'] != 0].iloc[0]

            # Normalize to ensure the first non-zero value is 1
            data.loc[:, 'value'] = data['value'] / first_non_zero_value

        # Sort data by date
        data = data.sort_values('quarter')
        
        # Add the account as a column for identifying each account
        data['account'] = account

        # Append to the cumulative data
        filtered_data = pd.concat([filtered_data, data])

    if filtered_data.empty:
        print("No data available for the given filters, check parameters.")
        return
    
    # Determine the Y-axis label
    y_axis_title = 'Value'
    
    # Plot logic for different plot types
    if plot_type == "stacked":
        # Stacked area plot with raw values
        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    elif plot_type == "overlapping":
        # Overlapping area plot (using filled line plots to avoid stacking)
        fig = px.line(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Overlapping Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )

        # Add filled areas to create the overlapping effect
        for account in accounts:
            account_data = filtered_data[filtered_data['account'] == account]
            fig.add_scatter(
                x=account_data['quarter'],
                y=account_data['value'],
                mode='lines',
                line=dict(width=0.5),
                fill='tozeroy',
                name=account,
                legendgroup=account,  # Group line and area under the same legend
                showlegend=False  # Hide the second entry for the filled area
            )

    elif plot_type == "lines":
        # Line-only plot with no filling
        fig = px.line(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Line-Only Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )

    elif plot_type == "100_stacked":
        # 100% stacked area plot (scaled to show percentages)
        filtered_data['total_per_quarter'] = filtered_data.groupby('quarter')['value'].transform('sum')
        filtered_data['value'] = (filtered_data['value'] / filtered_data['total_per_quarter']) * 100
        y_axis_title = 'Percentage Contribution (%)'
        
        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'100% Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    elif plot_type == "normalized_stacked":
        # Normalized stacked area plot (no percentage, just normalized values for each account)
        y_axis_title = 'Normalized Value'

        fig = px.area(
            filtered_data,
            x='quarter',
            y='value',
            color='account',
            title=f'Normalized Stacked Area Plot of Accounts for {company_name}',
            labels={'quarter': 'Quarter', 'value': y_axis_title},
            template='plotly_white'
        )
    
    # Update layout
    fig.update_layout(xaxis_title='Quarter', yaxis_title=y_axis_title, showlegend=True)
    
    return fig  # Return the figure, not the DataFrame
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Initialize a subplot figure with 2 rows and 1 column
fig = make_subplots(rows=2, cols=1, subplot_titles=("Stacked Plot", "100% Stacked Plot"))

# Call plot_time_series for the stacked plot and add to the first subplot (row 1)
fig_stacked = plot_time_series(
    company_name=uv['company_name'][7],
    accounts=['01.01.01', '01.01.02', '01.01.03', '01.01.04'],
    plot_type="stacked",
    start_date='2013-12-31',
)

# Add the traces from the stacked plot to the first subplot
for trace in fig_stacked['data']:
    fig.add_trace(trace, row=1, col=1)

# Call plot_time_series for the 100% stacked plot and add to the second subplot (row 2)
fig_100_stacked = plot_time_series(
    company_name=uv['company_name'][7],
    accounts=['01.01.01', '01.01.02', '01.01.03', '01.01.04'],
    plot_type="100_stacked",
    start_date='2013-12-31',
)

# Add the traces from the 100% stacked plot to the second subplot
for trace in fig_100_stacked['data']:
    fig.add_trace(trace, row=2, col=1)

# Update the layout for the entire figure
fig.update_layout(
    title_text="Comparison of Stacked and 100% Stacked Plots",
    height=800,
    showlegend=False  # Hide the legend since it might overlap
)

# Show the plot
fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd

def plot_company_comparison(df, companies, account, start_date=None, end_date=None, plot_type="lines"):
    """
    Compare a financial metric (account) across multiple companies, filtered by 'df_type',
    and display the average of the companies.
    
    Args:
    - df: DataFrame containing the financial data.
    - companies: List of company names to compare.
    - account: The financial account to be plotted (e.g., '03.11 - Lucro do Período').
    - start_date: Start date for filtering the data (optional).
    - end_date: End date for filtering the data (optional).
    - plot_type: Determines whether to plot 'lines' or 'normalized'.
    """
    # Try 'DFs Consolidadas' first
    if (df['type'] == 'DFs Consolidadas').any():
        df_type = 'DFs Consolidadas'
    else:
        df_type = 'DFs Individuais'

    # Filter data for the specified companies, account, and df_type
    data = df[
        (df['company_name'].isin(companies)) &
        (df['account'] == account) &
        (df['type'] == df_type)
    ].copy()  # Make a deep copy to avoid SettingWithCopyWarning

    # Apply start and end date filters if provided
    if start_date:
        data = data[data['quarter'] >= pd.to_datetime(start_date)].copy()  # Copy after filtering
    if end_date:
        data = data[data['quarter'] <= pd.to_datetime(end_date)].copy()  # Copy after filtering

    if data.empty:
        print("No data available for the given filters.")
        return

    # Get the description dynamically from the DataFrame based on the 'account' field
    description = data['description'].dropna().iloc[0] if 'description' in data.columns and not data['description'].isna().all() else account

    # Create the figure
    fig = go.Figure()

    # Add line plot for each company (no markers)
    for company in companies:
        company_data = data[data['company_name'] == company].sort_values('quarter').copy()  # Avoid modifying the original DataFrame

        if not company_data.empty:
            if plot_type == "normalized":
                # Try to get the first non-zero value for normalization
                non_zero_values = company_data['value'][company_data['value'] != 0]

                if not non_zero_values.empty:
                    first_non_zero_value = non_zero_values.iloc[0]
                    # Normalize the values: scale from 1 to proportional max_value
                    company_data.loc[:, 'normalized_value'] = company_data['value'] / first_non_zero_value
                else:
                    print(f"Warning: No non-zero values for {company}. Skipping normalization.")
                    company_data.loc[:, 'normalized_value'] = company_data['value']  # No normalization applied

                # Plot normalized lines
                fig.add_trace(go.Scatter(
                    x=company_data['quarter'],
                    y=company_data['normalized_value'],
                    mode='lines',
                    name=f"{company} (normalized)",
                    hoverinfo='x+y'
                ))
            else:
                # Plot regular lines
                fig.add_trace(go.Scatter(
                    x=company_data['quarter'],
                    y=company_data['value'],
                    mode='lines',
                    name=company,
                    hoverinfo='x+y'
                ))

    if plot_type == "normalized":
        # Calculate the average of actual values for each quarter
        average_data = data.groupby('quarter')['value'].mean().reset_index()

        # Normalize the average value (just like individual company values)
        first_non_zero_avg = average_data['value'][average_data['value'] != 0].iloc[0]
        average_data['normalized_value'] = average_data['value'] / first_non_zero_avg

        # Add the average normalized line to the plot
        fig.add_trace(go.Scatter(
            x=average_data['quarter'],
            y=average_data['normalized_value'],
            mode='lines',
            name='Average (normalized)',
            line=dict(dash='dash', color='black'),
            hoverinfo='x+y'
        ))

        y_axis_title = 'Normalized Value (Proportional to 1)'
    else:
        # Calculate the average value for each quarter
        average_data = data.groupby('quarter')['value'].mean().reset_index()

        # Add the average line to the plot
        fig.add_trace(go.Scatter(
            x=average_data['quarter'],
            y=average_data['value'],
            mode='lines',
            name='Average',
            line=dict(dash='dash', color='black'),
            hoverinfo='x+y'
        ))

        y_axis_title = description

    # Update layout
    fig.update_layout(
        title=f'Comparison of {account} - {description}',
        xaxis_title='Quarter',
        yaxis_title=y_axis_title,
        template='plotly_white',
        showlegend=True
    )

    # Show plot
    fig.show()

    return data

# %%
# Example usage:
data = plot_company_comparison(
    df=df,  # Your DataFrame containing the financial data
    companies=['OI SA', 'TELEFONICA BRASIL SA', 'TIM SA'],
    account='01.01.01',  # Example account code for "Lucro do Período"
    start_date='2013-12-31',  # Filter from this date
    end_date='2020-12-31',     # Optional: Filter until this date
    plot_type="lines"  # Choose between "lines" and "normalized"
)
# Example usage:
data = plot_company_comparison(
    df=df,  # Your DataFrame containing the financial data
    companies=['OI SA', 'TELEFONICA BRASIL SA', 'TIM SA'],
    account='03.01',  # Example account code for "Lucro do Período"
    # start_date='2020-12-31',  # Filter from this date
    # end_date='2023-12-31',     # Optional: Filter until this date
    plot_type="normalized"  # Choose between "lines" and "normalized"
)

# %% [markdown]
# ### World Data

# %%
serie = '1'

url = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{serie}/dados?formato=json'
response = requests.get(url)
data = response.json()
data = pd.DataFrame(data)

# %%
def get_median_data(df):
    # Remover a informação de fuso horário (timezone) antes de converter para períodos
    df.index = df.index.tz_localize(None)

    # Criar uma coluna de trimestre ('Quarter')
    df['quarter'] = df.index.to_period('Q')

    # Calcular a mediana de 'Adj Close' por trimestre
    median = df.groupby('quarter')['value'].median()
    # mean = df.groupby('quarter')['Adj Close'].mean()

    # Convert last_dates to the actual last date of the quarter
    # Using the 'Q' period information from 'Quarter'
    last_quarter_dates = df['quarter'].map(lambda x: x.end_time)

    # Converter as datas para manter apenas a parte da data (sem tempo)
    last_quarter_dates = last_quarter_dates.dt.date.drop_duplicates()

    # Criar um DataFrame com a última data correta de cada trimestre e a mediana trimestral
    quarterly_summary = pd.DataFrame({
        'quarter': last_quarter_dates.values,  # Drop duplicates to keep one last date per quarter
        'median': median.values, 
    })


    return quarterly_summary

# %%
comm = ['ELETROMIDIA SA', 'ALGAR TELECOM SA', 'BRISANET PARTICIPACOES SA',
       'DESKTOP SA', 'GIGA MAIS FIBRA TELECOMUNICACOES SA', 'OI SA',
       'TELEC BRASILEIRAS SA TELEBRAS', 'TELEFONICA BRASIL SA', 'TIM SA',
       'UNIFIQUE TELECOMUNICACOES SA']

# %%
# sector = 'COMUNICACOES'
db_file = f"..\data\{settings.db_filepath}"

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Fetch all table names excluding internal SQLite tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = cursor.fetchall()

df = pd.read_sql_query(f"SELECT * FROM company_info", conn)
companies = df[df['ticker_codes'] != '']
companies = companies[['cvm_code', 'company_name', 'ticker', 'ticker_codes']].drop_duplicates()

# %%
# Get the unique ticker codes from the 'ticker_codes' column
ticker_codes = companies['ticker_codes'].unique()

# Split the comma-separated ticker codes, flatten the list, and append '.SA' if necessary
ticker_list = [f"{code.strip()}.SA" if not code.strip().endswith('.SA') else code.strip() 
               for tickers in ticker_codes for code in tickers.split(',') if code]

ticker_list

# %%
# Get the unique ticker codes from the 'ticker_codes' column
ticker_codes = companies['ticker_codes'].unique()

# Split the comma-separated ticker codes, flatten the list, and append '.SA' if necessary
ticker_list = [f"{code.strip()}.SA" if not code.strip().endswith('.SA') else code.strip() 
               for tickers in ticker_codes for code in tickers.split(',') if code]

# Remove empty strings (if any) and display the result
companies = [code for code in ticker_list if code]
len(companies)

# %%
# Baixar os dados
last_date = '1900-01-01'
# companies = ['AAPL', 'ITUB3.SA', 'ITUB4.SA', 'GOOG']
data = yf.download(' '.join(companies), start=last_date)

# %%
historical_data = {}
companies2 = []
data_error = {}
start_time = time.time()
for i, company in enumerate(companies):
    try:
        # Selecionar os dados de company e remover NaNs
        df = data.xs(company, axis=1, level=1).dropna()
        df['value'] = df['Adj Close']

        # get median data from df
        df = get_median_data(df)

        historical_data[company] = df
        companies2.append(company)
        extra_info = [company]
        print_info(i, extra_info, start_time, len(companies))
    except Exception as e:
        data_error[company] = company

# %%
# Now find the overall min and max quarter across all tickers
all_quarters = [data['quarter'] for data in historical_data.values()]
max_quarter = pd.concat(all_quarters).max()
previous_quarter = pd.Period(max_quarter, freq='Q') - 1
last_date = previous_quarter.end_time.date()

data2 = yf.download(' '.join(companies2), start=last_date)

# %% [markdown]
# ### Yahoo Data

# %%
def load_data(files):
    """
    Load financial data from the database and process it into DataFrames.
    
    Args:
        files (str): The name part of the database file to load.

    Returns:
        dict: A dictionary where keys are sectors and values are DataFrames containing the NSD data for that sector.
    """
    try:
        db_file = os.path.join(settings.data_folder, f"{settings.db_filepath.split('.')[0]} {files}.db")
        db_file = 'D:/Fausto Stangler/Documentos/Python/FLY/backend/data/b3 standard.db'
        conn = sqlite3.connect(db_file)
        cursor = conn.cursor()

        # Fetch all table names excluding internal SQLite tables
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
        tables = cursor.fetchall()

        dfs = {}
        total_lines = 0
        start_time = time.time()  # Initialize start time for progress tracking

        # Iterate through each table (sector) and process the data
        for i, table in enumerate(tables):
            try:
                sector = table[0]
                df = pd.read_sql_query(f"SELECT * FROM {sector}", conn)

                # Normalize date columns to datetime format
                df['quarter'] = pd.to_datetime(df['quarter'], errors='coerce')

                # Normalize numeric columns
                df['value'] = pd.to_numeric(df['value'], errors='coerce')

                # Fill missing 'value' with 0
                df['value'] = df['value'].fillna(0)

                # Identify rows where 'account' is missing or NaN and 'value' has been set to 0
                missing_account = df['account'].isna() | df['account'].str.strip().eq('')
                df.loc[missing_account, 'account'] = '0'  # Set 'account' to '0' (as text) for these rows

                # Filter out only the latest versions for each group
                # df, _ = self.filter_newer_versions(df)
                dfs[sector] = df  # Store the DataFrame with the sector as the key
                total_lines += len(df)  # Update the total number of processed lines

                # Display progress
                extra_info = [f'Loaded {len(df)} items from {sector} in {files}, total {total_lines}']
                print_info(i, extra_info, start_time, len(tables))  # Removed the total_files argument

                print('break')
                break

            except Exception as e:
                # system.log_error(f"Error processing table {table}: {e}")
                print(e)

        conn.close()
        return dfs

    except Exception as e:
        print(e)
       # system.log_error(f"Error loading existing financial statements: {e}")
        return {}

# %%
def load_company_data():

    company_data = {}

    try:
        db_file = os.path.join(settings.data_folder, f"{settings.db_filepath}")
        db_file = 'D:/Fausto Stangler/Documentos/Python/FLY/backend/data/b3.db'
        conn = sqlite3.connect(db_file)
        cursor = conn.cursor()

        cursor.execute(f"SELECT * FROM {settings.company_table}")

        for row in cursor.fetchall():
            company_name = row[settings.company_columns.index('company_name')]
            company_data[company_name] = dict(zip(settings.company_columns, row))

    except Exception as e:
        # system.log_error(e)
        print(e)

    return company_data

# %%
def get_median_data(df):
    # Remover a informação de fuso horário (timezone) antes de converter para períodos
    df.index = df.index.tz_localize(None)

    # Criar uma coluna de trimestre ('Quarter')
    df['quarter'] = df.index.to_period('Q')

    # Calcular a mediana de 'Adj Close' por trimestre
    median = df.groupby('quarter')['value'].median()
    # mean = df.groupby('quarter')['Adj Close'].mean()

    # Convert last_dates to the actual last date of the quarter
    # Using the 'Q' period information from 'Quarter'
    last_quarter_dates = df['quarter'].map(lambda x: x.end_time)

    # Converter as datas para manter apenas a parte da data (sem tempo)
    last_quarter_dates = last_quarter_dates.dt.date.drop_duplicates()

    # Criar um DataFrame com a última data correta de cada trimestre e a mediana trimestral
    quarterly_summary = pd.DataFrame({
        'quarter': last_quarter_dates.values,  # Drop duplicates to keep one last date per quarter
        'median': median.values, 
    })


    return quarterly_summary

# %%
statements_data = load_data(settings.statements_standard)
df_statements = statements_data['COMUNICACOES']
# Out:
# 7.14% 1+13, 0.480669s per item, Time: 0h 00m 00s + 0h 00m 06s Loaded 90669 items from COMUNICACOES in standard, total 90669
# break

# %%
all_companies = load_company_data()
df_companies = pd.DataFrame(all_companies).T.reset_index(drop=True)

# %%
# merge statements and company info

columns = ['company_name']
cols_to_merge = columns + ['cvm_code', 'ticker', 'ticker_codes', 'isin_codes', 'listing']
# Merge the two DataFrames on the 'company_name' column
df_statements_companies = pd.merge(df_statements, df_companies[cols_to_merge], on=columns, how='left')

list_of_tickers = df_statements_companies[['company_name', 'ticker_codes']].drop_duplicates()
list_of_quarters = df_statements_companies[['company_name', 'ticker_codes', 'quarter']].drop_duplicates()

# %%
# get historical data from yahoo finance

historical_data = {}
last_date = '1950-01-01'

# Iterate over each row and process tickers
for index, row in list_of_tickers.iterrows():
    company_name = row['company_name']
    tickers = row['ticker_codes']

    # Ensure that tickers are passed as a list by splitting any comma-separated string
    tickers = tickers.split(',') if isinstance(tickers, str) else tickers

    for ticker in tickers:

        if ticker:
            print(company_name, ticker)
            df = yf.download(ticker + '.SA', start=last_date, group_by='ticker', progress=False)
            df['value'] = df['Adj Close']
            df = get_median_data(df)

        historical_data[ticker] = df
    # break
# Out:
# ELETROMIDIA SA ELMD3
# BRISANET PARTICIPACOES SA BRIT3
# DESKTOP SA DESK3
# OI SA OIBR3
# OI SA OIBR4
# TELEC BRASILEIRAS SA TELEBRAS TELB3
# TELEC BRASILEIRAS SA TELEBRAS TELB4
# TELEFONICA BRASIL SA VIVT3
# TIM SA TIMS3
# UNIFIQUE TELECOMUNICACOES SA FIQE3

# %%
# create new historical data rows

new_rows = []
for i, row in list_of_quarters.iterrows():
    company_name = row['company_name']
    quarter = row['quarter']
    tickers = row['ticker_codes']

    tickers = tickers.split(',') if isinstance(tickers, str) else tickers
    for ticker in tickers:
        if ticker:
            # Separate ticker into no digits and only digits
            tick = ''.join([char for char in ticker if not char.isdigit()])  # Ticker without digits
            ticker_digit = ''.join([char for char in ticker if char.isdigit()])  # Only digits

            mask = df_statements_companies['company_name'] == company_name
            mask&= df_statements_companies['quarter'] == quarter
            mask&= df_statements_companies['ticker'] == tick

            new_row = df_statements_companies[mask].iloc[0].copy()

            # Modify the necessary columns in the copied row
            new_row['type'] = 'Cotações Históricas'
            new_row['frame'] = settings.tipos_acoes[ticker_digit]
            new_row['account'] = f"99.{ticker_digit}"  # ticker_digit is assumed to be extracted from the original ticker
            new_row['description'] = 'Cotação Mediana do Trimestre'

            # Ensure 'quarter' in 'historical_data' is converted to datetime
            df_historical_data = historical_data.get(tick + ticker_digit, pd.DataFrame())  # Use .get() to avoid KeyError if key doesn't exist
            if df_historical_data.empty:
                new_value = pd.NA
            else:
                df_historical_data['quarter'] = pd.to_datetime(df_historical_data['quarter'])

                # Filter the 'historical_data' for the correct 'quarter' and get the 'median' value
                mask = df_historical_data['quarter'] == pd.to_datetime(quarter)
                new_value = df_historical_data[mask]['median'].values

                # If no values are found, set to pd.NA
                if len(new_value) == 0:
                    new_value = pd.NA
                else:
                    new_value = new_value[0]  # Extract the actual median value

            # Set the new value in the new row
            new_row['value'] = new_value


            new_rows.append(new_row)
            print(company_name, quarter, tick, ticker_digit)
# Out:
# ELETROMIDIA SA 2019-12-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2020-03-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2020-06-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2020-09-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2020-12-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2021-03-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2021-06-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2021-09-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2021-12-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2022-03-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2022-06-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2022-09-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2022-12-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2023-03-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2023-06-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2023-09-30 00:00:00 ELMD 3
# ELETROMIDIA SA 2023-12-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2024-03-31 00:00:00 ELMD 3
# ELETROMIDIA SA 2024-06-30 00:00:00 ELMD 3
# BRISANET PARTICIPACOES SA 2020-12-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2021-03-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2021-06-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2021-09-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2021-12-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2022-03-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2022-06-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2022-09-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2022-12-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2023-03-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2023-06-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2023-09-30 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2023-12-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2024-03-31 00:00:00 BRIT 3
# BRISANET PARTICIPACOES SA 2024-06-30 00:00:00 BRIT 3
# DESKTOP SA 2020-12-31 00:00:00 DESK 3
# DESKTOP SA 2021-03-31 00:00:00 DESK 3
# DESKTOP SA 2021-06-30 00:00:00 DESK 3
# DESKTOP SA 2021-09-30 00:00:00 DESK 3
# DESKTOP SA 2021-12-31 00:00:00 DESK 3
# DESKTOP SA 2022-03-31 00:00:00 DESK 3
# DESKTOP SA 2022-06-30 00:00:00 DESK 3
# DESKTOP SA 2022-09-30 00:00:00 DESK 3
# DESKTOP SA 2022-12-31 00:00:00 DESK 3
# DESKTOP SA 2023-03-31 00:00:00 DESK 3
# DESKTOP SA 2023-06-30 00:00:00 DESK 3
# DESKTOP SA 2023-09-30 00:00:00 DESK 3
# DESKTOP SA 2023-12-31 00:00:00 DESK 3
# DESKTOP SA 2024-03-31 00:00:00 DESK 3
# DESKTOP SA 2024-06-30 00:00:00 DESK 3
# OI SA 2010-12-31 00:00:00 OIBR 3
# OI SA 2010-12-31 00:00:00 OIBR 4
# OI SA 2011-03-31 00:00:00 OIBR 3
# OI SA 2011-03-31 00:00:00 OIBR 4
# OI SA 2011-06-30 00:00:00 OIBR 3
# OI SA 2011-06-30 00:00:00 OIBR 4
# OI SA 2011-09-30 00:00:00 OIBR 3
# OI SA 2011-09-30 00:00:00 OIBR 4
# OI SA 2011-12-31 00:00:00 OIBR 3
# OI SA 2011-12-31 00:00:00 OIBR 4
# OI SA 2012-03-31 00:00:00 OIBR 3
# OI SA 2012-03-31 00:00:00 OIBR 4
# OI SA 2012-06-30 00:00:00 OIBR 3
# OI SA 2012-06-30 00:00:00 OIBR 4
# OI SA 2012-09-30 00:00:00 OIBR 3
# OI SA 2012-09-30 00:00:00 OIBR 4
# OI SA 2012-12-31 00:00:00 OIBR 3
# OI SA 2012-12-31 00:00:00 OIBR 4
# OI SA 2013-03-31 00:00:00 OIBR 3
# OI SA 2013-03-31 00:00:00 OIBR 4
# OI SA 2013-06-30 00:00:00 OIBR 3
# OI SA 2013-06-30 00:00:00 OIBR 4
# OI SA 2013-09-30 00:00:00 OIBR 3
# OI SA 2013-09-30 00:00:00 OIBR 4
# OI SA 2013-12-31 00:00:00 OIBR 3
# OI SA 2013-12-31 00:00:00 OIBR 4
# OI SA 2014-03-31 00:00:00 OIBR 3
# OI SA 2014-03-31 00:00:00 OIBR 4
# OI SA 2014-06-30 00:00:00 OIBR 3
# OI SA 2014-06-30 00:00:00 OIBR 4
# OI SA 2014-09-30 00:00:00 OIBR 3
# OI SA 2014-09-30 00:00:00 OIBR 4
# OI SA 2014-12-31 00:00:00 OIBR 3
# OI SA 2014-12-31 00:00:00 OIBR 4
# OI SA 2015-03-31 00:00:00 OIBR 3
# OI SA 2015-03-31 00:00:00 OIBR 4
# OI SA 2015-06-30 00:00:00 OIBR 3
# OI SA 2015-06-30 00:00:00 OIBR 4
# OI SA 2015-09-30 00:00:00 OIBR 3
# OI SA 2015-09-30 00:00:00 OIBR 4
# OI SA 2015-12-31 00:00:00 OIBR 3
# OI SA 2015-12-31 00:00:00 OIBR 4
# OI SA 2016-03-31 00:00:00 OIBR 3
# OI SA 2016-03-31 00:00:00 OIBR 4
# OI SA 2016-06-30 00:00:00 OIBR 3
# OI SA 2016-06-30 00:00:00 OIBR 4
# OI SA 2016-09-30 00:00:00 OIBR 3
# OI SA 2016-09-30 00:00:00 OIBR 4
# OI SA 2016-12-31 00:00:00 OIBR 3
# OI SA 2016-12-31 00:00:00 OIBR 4
# OI SA 2017-03-31 00:00:00 OIBR 3
# OI SA 2017-03-31 00:00:00 OIBR 4
# OI SA 2017-06-30 00:00:00 OIBR 3
# OI SA 2017-06-30 00:00:00 OIBR 4
# OI SA 2017-09-30 00:00:00 OIBR 3
# OI SA 2017-09-30 00:00:00 OIBR 4
# OI SA 2017-12-31 00:00:00 OIBR 3
# OI SA 2017-12-31 00:00:00 OIBR 4
# OI SA 2018-03-31 00:00:00 OIBR 3
# OI SA 2018-03-31 00:00:00 OIBR 4
# OI SA 2018-06-30 00:00:00 OIBR 3
# OI SA 2018-06-30 00:00:00 OIBR 4
# OI SA 2018-09-30 00:00:00 OIBR 3
# OI SA 2018-09-30 00:00:00 OIBR 4
# OI SA 2018-12-31 00:00:00 OIBR 3
# OI SA 2018-12-31 00:00:00 OIBR 4
# OI SA 2019-03-31 00:00:00 OIBR 3
# OI SA 2019-03-31 00:00:00 OIBR 4
# OI SA 2019-06-30 00:00:00 OIBR 3
# OI SA 2019-06-30 00:00:00 OIBR 4
# OI SA 2019-09-30 00:00:00 OIBR 3
# OI SA 2019-09-30 00:00:00 OIBR 4
# OI SA 2019-12-31 00:00:00 OIBR 3
# OI SA 2019-12-31 00:00:00 OIBR 4
# OI SA 2020-03-31 00:00:00 OIBR 3
# OI SA 2020-03-31 00:00:00 OIBR 4
# OI SA 2020-06-30 00:00:00 OIBR 3
# OI SA 2020-06-30 00:00:00 OIBR 4
# OI SA 2020-09-30 00:00:00 OIBR 3
# OI SA 2020-09-30 00:00:00 OIBR 4
# OI SA 2020-12-31 00:00:00 OIBR 3
# OI SA 2020-12-31 00:00:00 OIBR 4
# OI SA 2021-03-31 00:00:00 OIBR 3
# OI SA 2021-03-31 00:00:00 OIBR 4
# OI SA 2021-06-30 00:00:00 OIBR 3
# OI SA 2021-06-30 00:00:00 OIBR 4
# OI SA 2021-09-30 00:00:00 OIBR 3
# OI SA 2021-09-30 00:00:00 OIBR 4
# OI SA 2021-12-31 00:00:00 OIBR 3
# OI SA 2021-12-31 00:00:00 OIBR 4
# OI SA 2022-03-31 00:00:00 OIBR 3
# OI SA 2022-03-31 00:00:00 OIBR 4
# OI SA 2022-06-30 00:00:00 OIBR 3
# OI SA 2022-06-30 00:00:00 OIBR 4
# OI SA 2022-09-30 00:00:00 OIBR 3
# OI SA 2022-09-30 00:00:00 OIBR 4
# OI SA 2022-12-31 00:00:00 OIBR 3
# OI SA 2022-12-31 00:00:00 OIBR 4
# OI SA 2023-03-31 00:00:00 OIBR 3
# OI SA 2023-03-31 00:00:00 OIBR 4
# OI SA 2023-06-30 00:00:00 OIBR 3
# OI SA 2023-06-30 00:00:00 OIBR 4
# OI SA 2023-09-30 00:00:00 OIBR 3
# OI SA 2023-09-30 00:00:00 OIBR 4
# OI SA 2023-12-31 00:00:00 OIBR 3
# OI SA 2023-12-31 00:00:00 OIBR 4
# OI SA 2024-03-31 00:00:00 OIBR 3
# OI SA 2024-03-31 00:00:00 OIBR 4
# OI SA 2024-06-30 00:00:00 OIBR 3
# OI SA 2024-06-30 00:00:00 OIBR 4
# TELEC BRASILEIRAS SA TELEBRAS 2010-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2010-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2011-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2011-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2011-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2011-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2011-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2011-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2011-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2011-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2012-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2012-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2012-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2012-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2012-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2012-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2012-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2012-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2013-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2013-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2013-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2013-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2013-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2013-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2013-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2013-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2014-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2014-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2014-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2014-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2014-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2014-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2014-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2014-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2015-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2015-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2015-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2015-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2015-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2015-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2015-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2015-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2016-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2016-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2016-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2016-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2016-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2016-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2016-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2016-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2017-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2017-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2017-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2017-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2017-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2017-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2017-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2017-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2018-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2018-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2018-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2018-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2018-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2018-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2018-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2018-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2019-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2019-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2019-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2019-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2019-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2019-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2019-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2019-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2020-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2020-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2020-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2020-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2020-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2020-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2020-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2020-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2021-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2021-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2021-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2021-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2021-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2021-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2021-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2021-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2022-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2022-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2022-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2022-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2022-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2022-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2022-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2022-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2023-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2023-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2023-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2023-06-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2023-09-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2023-09-30 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2023-12-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2023-12-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2024-03-31 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2024-03-31 00:00:00 TELB 4
# TELEC BRASILEIRAS SA TELEBRAS 2024-06-30 00:00:00 TELB 3
# TELEC BRASILEIRAS SA TELEBRAS 2024-06-30 00:00:00 TELB 4
# TELEFONICA BRASIL SA 2010-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2011-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2011-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2011-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2011-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2012-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2012-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2012-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2012-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2013-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2013-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2013-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2013-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2014-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2014-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2014-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2014-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2015-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2015-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2015-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2015-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2016-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2016-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2016-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2016-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2017-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2017-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2017-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2017-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2018-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2018-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2018-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2018-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2019-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2019-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2019-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2019-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2020-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2020-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2020-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2020-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2021-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2021-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2021-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2021-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2022-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2022-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2022-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2022-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2023-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2023-06-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2023-09-30 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2023-12-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2024-03-31 00:00:00 VIVT 3
# TELEFONICA BRASIL SA 2024-06-30 00:00:00 VIVT 3
# TIM SA 2018-12-31 00:00:00 TIMS 3
# TIM SA 2019-03-31 00:00:00 TIMS 3
# TIM SA 2019-06-30 00:00:00 TIMS 3
# TIM SA 2019-09-30 00:00:00 TIMS 3
# TIM SA 2019-12-31 00:00:00 TIMS 3
# TIM SA 2020-03-31 00:00:00 TIMS 3
# TIM SA 2020-06-30 00:00:00 TIMS 3
# TIM SA 2020-09-30 00:00:00 TIMS 3
# TIM SA 2020-12-31 00:00:00 TIMS 3
# TIM SA 2021-03-31 00:00:00 TIMS 3
# TIM SA 2021-06-30 00:00:00 TIMS 3
# TIM SA 2021-09-30 00:00:00 TIMS 3
# TIM SA 2021-12-31 00:00:00 TIMS 3
# TIM SA 2022-03-31 00:00:00 TIMS 3
# TIM SA 2022-06-30 00:00:00 TIMS 3
# TIM SA 2022-09-30 00:00:00 TIMS 3
# TIM SA 2022-12-31 00:00:00 TIMS 3
# TIM SA 2023-03-31 00:00:00 TIMS 3
# TIM SA 2023-06-30 00:00:00 TIMS 3
# TIM SA 2023-09-30 00:00:00 TIMS 3
# TIM SA 2023-12-31 00:00:00 TIMS 3
# TIM SA 2024-03-31 00:00:00 TIMS 3
# TIM SA 2024-06-30 00:00:00 TIMS 3
# UNIFIQUE TELECOMUNICACOES SA 2020-12-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2021-03-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2021-06-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2021-09-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2021-12-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2022-03-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2022-06-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2022-09-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2022-12-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2023-03-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2023-06-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2023-09-30 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2023-12-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2024-03-31 00:00:00 FIQE 3
# UNIFIQUE TELECOMUNICACOES SA 2024-06-30 00:00:00 FIQE 3

# %%
# insert new rows into df_statements_companies

df_final = pd.concat([df_statements_companies, pd.DataFrame(new_rows)], ignore_index=True).drop_duplicates()

mask = df_final['ticker'] == 'ELMD'
# mask&= df_historical_statements_2['quarter'] == '2020-12-31'
mask&= df_final['type'] == 'Cotações Históricas'

df_final

# sort and select only statement columns
# Out:
#           nsd        sector         subsector                   segment  \
# 0       99116  COMUNICACOES             MIDIA  PUBLICIDADE E PROPAGANDA
# 1       99116  COMUNICACOES             MIDIA  PUBLICIDADE E PROPAGANDA
# 2       99116  COMUNICACOES             MIDIA  PUBLICIDADE E PROPAGANDA
# 3       99116  COMUNICACOES             MIDIA  PUBLICIDADE E PROPAGANDA
# 4       99116  COMUNICACOES             MIDIA  PUBLICIDADE E PROPAGANDA
# ...       ...           ...               ...                       ...
# 91026  129891  COMUNICACOES  TELECOMUNICACOES          TELECOMUNICACOES
# 91027  131935  COMUNICACOES  TELECOMUNICACOES          TELECOMUNICACOES
# 91028  134906  COMUNICACOES  TELECOMUNICACOES          TELECOMUNICACOES
# 91029  137478  COMUNICACOES  TELECOMUNICACOES          TELECOMUNICACOES
# 91030  140491  COMUNICACOES  TELECOMUNICACOES          TELECOMUNICACOES
#
#                        company_name    quarter version                 type  \
# 0                    ELETROMIDIA SA 2019-12-31       1     DFs Consolidadas
# 1                    ELETROMIDIA SA 2019-12-31       1     DFs Consolidadas
# 2                    ELETROMIDIA SA 2019-12-31       1     DFs Consolidadas
# 3                    ELETROMIDIA SA 2019-12-31       1     DFs Consolidadas
# 4                    ELETROMIDIA SA 2019-12-31       1     DFs Consolidadas
# ...                             ...        ...     ...                  ...
# 91026  UNIFIQUE TELECOMUNICACOES SA 2023-06-30       1  Cotações Históricas
# 91027  UNIFIQUE TELECOMUNICACOES SA 2023-09-30       1  Cotações Históricas
# 91028  UNIFIQUE TELECOMUNICACOES SA 2023-12-31       1  Cotações Históricas
# 91029  UNIFIQUE TELECOMUNICACOES SA 2024-03-31       1  Cotações Históricas
# 91030  UNIFIQUE TELECOMUNICACOES SA 2024-06-30       1  Cotações Históricas
#
#                            frame      account  \
# 0      Balanço Patrimonial Ativo           01
# 1      Balanço Patrimonial Ativo        01.01
# 2      Balanço Patrimonial Ativo     01.01.01
# 3      Balanço Patrimonial Ativo  01.01.01.01
# 4      Balanço Patrimonial Ativo  01.01.01.02
# ...                          ...          ...
# 91026      Ações Ordinárias (ON)         99.3
# 91027      Ações Ordinárias (ON)         99.3
# 91028      Ações Ordinárias (ON)         99.3
# 91029      Ações Ordinárias (ON)         99.3
# 91030      Ações Ordinárias (ON)         99.3
#
#                                         description         value cvm_code  \
# 0                                       Ativo Total  2905300000.0    25569
# 1                   Ativo Circulante de Curto Prazo  1061320000.0    25569
# 2      Caixa e Equivalentes de Caixa de Curto Prazo   380180000.0    25569
# 3                     Caixa e Bancos de Curto Prazo   130980000.0    25569
# 4                Aplicações Líquidas de Curto Prazo   249200000.0    25569
# ...                                             ...           ...      ...
# 91026                  Cotação Mediana do Trimestre      3.278778    26050
# 91027                  Cotação Mediana do Trimestre      3.719842    26050
# 91028                  Cotação Mediana do Trimestre      3.490817    26050
# 91029                  Cotação Mediana do Trimestre      3.726683    26050
# 91030                  Cotação Mediana do Trimestre      3.544215    26050
#
#       ticker ticker_codes    isin_codes           listing
# 0       ELMD        ELMD3  BRELMDACNOR3  CIA NOVO MERCADO
# 1       ELMD        ELMD3  BRELMDACNOR3  CIA NOVO MERCADO
# 2       ELMD        ELMD3  BRELMDACNOR3  CIA NOVO MERCADO
# 3       ELMD        ELMD3  BRELMDACNOR3  CIA NOVO MERCADO
# 4       ELMD        ELMD3  BRELMDACNOR3  CIA NOVO MERCADO
# ...      ...          ...           ...               ...
# 91026   FIQE        FIQE3  BRFIQEACNOR5  CIA NOVO MERCADO
# 91027   FIQE        FIQE3  BRFIQEACNOR5  CIA NOVO MERCADO
# 91028   FIQE        FIQE3  BRFIQEACNOR5  CIA NOVO MERCADO
# 91029   FIQE        FIQE3  BRFIQEACNOR5  CIA NOVO MERCADO
# 91030   FIQE        FIQE3  BRFIQEACNOR5  CIA NOVO MERCADO
#
# [91031 rows x 17 columns]

# %% [markdown]
# ### Finantial Ratios

# %%
sector = 'COMUNICACOES'
db_file = f"..\data\{settings.db_filepath.split('.')[0]} {settings.markets_file}.db"

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Fetch all table names excluding internal SQLite tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';")
tables = cursor.fetchall()

df = pd.read_sql_query(f"SELECT * FROM {sector}", conn)
# df['account_description'] = df['account'] + ' - ' + df['description']
df['quarter'] = pd.to_datetime(df['quarter'])
# Store unique values

# %%
uv = {}
for col in df.columns:
    if col not in ['nsd', 'value']:
        uv[col] = sorted(df[col].unique().tolist())
uv
# Out:
# {'sector': ['COMUNICACOES'],
#  'subsector': ['MIDIA', 'TELECOMUNICACOES'],
#  'segment': ['PUBLICIDADE E PROPAGANDA', 'TELECOMUNICACOES'],
#  'company_name': ['ALGAR TELECOM SA',
#   'BRISANET PARTICIPACOES SA',
#   'DESKTOP SA',
#   'ELETROMIDIA SA',
#   'GIGA MAIS FIBRA TELECOMUNICACOES SA',
#   'OI SA',
#   'TELEC BRASILEIRAS SA TELEBRAS',
#   'TELEFONICA BRASIL SA',
#   'TIM SA',
#   'UNIFIQUE TELECOMUNICACOES SA'],
#  'quarter': [Timestamp('2010-12-31 00:00:00'),
#   Timestamp('2011-03-31 00:00:00'),
#   Timestamp('2011-06-30 00:00:00'),
#   Timestamp('2011-09-30 00:00:00'),
#   Timestamp('2011-12-31 00:00:00'),
#   Timestamp('2012-03-31 00:00:00'),
#   Timestamp('2012-06-30 00:00:00'),
#   Timestamp('2012-09-30 00:00:00'),
#   Timestamp('2012-12-31 00:00:00'),
#   Timestamp('2013-03-31 00:00:00'),
#   Timestamp('2013-06-30 00:00:00'),
#   Timestamp('2013-09-30 00:00:00'),
#   Timestamp('2013-12-31 00:00:00'),
#   Timestamp('2014-03-31 00:00:00'),
#   Timestamp('2014-06-30 00:00:00'),
#   Timestamp('2014-09-30 00:00:00'),
#   Timestamp('2014-12-31 00:00:00'),
#   Timestamp('2015-03-31 00:00:00'),
#   Timestamp('2015-06-30 00:00:00'),
#   Timestamp('2015-09-30 00:00:00'),
#   Timestamp('2015-12-31 00:00:00'),
#   Timestamp('2016-03-31 00:00:00'),
#   Timestamp('2016-06-30 00:00:00'),
#   Timestamp('2016-09-30 00:00:00'),
#   Timestamp('2016-12-31 00:00:00'),
#   Timestamp('2017-03-31 00:00:00'),
#   Timestamp('2017-06-30 00:00:00'),
#   Timestamp('2017-09-30 00:00:00'),
#   Timestamp('2017-12-31 00:00:00'),
#   Timestamp('2018-03-31 00:00:00'),
#   Timestamp('2018-06-30 00:00:00'),
#   Timestamp('2018-09-30 00:00:00'),
#   Timestamp('2018-12-31 00:00:00'),
#   Timestamp('2019-03-31 00:00:00'),
#   Timestamp('2019-06-30 00:00:00'),
#   Timestamp('2019-09-30 00:00:00'),
#   Timestamp('2019-12-31 00:00:00'),
#   Timestamp('2020-03-31 00:00:00'),
#   Timestamp('2020-06-30 00:00:00'),
#   Timestamp('2020-09-30 00:00:00'),
#   Timestamp('2020-12-31 00:00:00'),
#   Timestamp('2021-03-31 00:00:00'),
#   Timestamp('2021-06-30 00:00:00'),
#   Timestamp('2021-09-30 00:00:00'),
#   Timestamp('2021-12-31 00:00:00'),
#   Timestamp('2022-03-31 00:00:00'),
#   Timestamp('2022-06-30 00:00:00'),
#   Timestamp('2022-09-30 00:00:00'),
#   Timestamp('2022-12-31 00:00:00'),
#   Timestamp('2023-03-31 00:00:00'),
#   Timestamp('2023-06-30 00:00:00'),
#   Timestamp('2023-09-30 00:00:00'),
#   Timestamp('2023-12-31 00:00:00'),
#   Timestamp('2024-03-31 00:00:00'),
#   Timestamp('2024-06-30 00:00:00')],
#  'version': ['1', '2', '3', '4'],
#  'type': ['Cotações Históricas',
#   'DFs Consolidadas',
#   'DFs Individuais',
#   'Dados da Empresa'],
#  'frame': ['Balanço Patrimonial Ativo',
#   'Balanço Patrimonial Passivo',
#   'Composição do Capital',
#   'Cotação Mediana do Trimestre',
#   'Demonstração de Valor Adicionado',
#   'Demonstração do Fluxo de Caixa',
#   'Demonstração do Resultado'],
#  'account': ['00.01.01',
#   '00.01.02',
#   '00.02.01',
#   '00.02.02',
#   '01',
#   '01.01',
#   '01.01.01',
#   '01.01.01.01',
#   '01.01.01.02',
#   '01.01.02',
#   '01.01.02.01',
#   '01.01.02.02',
#   '01.01.03',
#   '01.01.03.01',
#   '01.01.03.01.01',
#   '01.01.03.01.02',
#   '01.01.03.01.03',
#   '01.01.03.02',
#   '01.01.04',
#   '01.01.04.01',
#   '01.01.04.02',
#   '01.01.04.03',
#   '01.01.05',
#   '01.01.06',
#   '01.01.07',
#   '01.01.09',
#   '01.02',
#   '01.02.01',
#   '01.02.01.02',
#   '01.02.01.03',
#   '01.02.01.04',
#   '01.02.01.05',
#   '01.02.01.06',
#   '01.02.01.07',
#   '01.02.01.08',
#   '01.02.01.09',
#   '01.02.02',
#   '01.02.02.01',
#   '01.02.02.01.01',
#   '01.02.02.01.02',
#   '01.02.02.01.03',
#   '01.02.02.02',
#   '01.02.03',
#   '01.02.03.01',
#   '01.02.03.02',
#   '01.02.04',
#   '01.02.04.01',
#   '01.02.04.01.01',
#   '01.02.04.01.02',
#   '01.02.04.01.03',
#   '01.02.04.02',
#   '01.02.04.02.01',
#   '02',
#   '02.01',
#   '02.01.01.01',
#   '02.01.01.02',
#   '02.01.02',
#   '02.01.02.01',
#   '02.01.02.02',
#   '02.01.03',
#   '02.01.03.01',
#   '02.01.03.01.01',
#   '02.01.03.01.02',
#   '02.01.03.01.03',
#   '02.01.03.02',
#   '02.01.03.03',
#   '02.01.04',
#   '02.01.04.01',
#   '02.01.04.01.01',
#   '02.01.04.01.02',
#   '02.01.04.02',
#   '02.01.04.03',
#   '02.01.05',
#   '02.01.05.01',
#   '02.01.05.01.01',
#   '02.01.05.01.03',
#   '02.01.05.01.04',
#   '02.01.05.02',
#   '02.01.05.02.01',
#   '02.01.05.02.02',
#   '02.01.05.02.03',
#   '02.01.05.02.04',
#   '02.01.05.02.09',
#   '02.01.06',
#   '02.01.06.01',
#   '02.01.06.01.01',
#   '02.01.06.01.02',
#   '02.01.06.01.03',
#   '02.01.06.01.04',
#   '02.01.06.02',
#   '02.01.06.02.01',
#   '02.01.06.02.02',
#   '02.01.06.02.03',
#   '02.02',
#   '02.02.01',
#   '02.02.01.01',
#   '02.02.01.01.01',
#   '02.02.01.01.02',
#   '02.02.01.02',
#   '02.02.01.03',
#   '02.02.02',
#   '02.02.02.01.04',
#   '02.02.03',
#   '02.02.04',
#   '02.02.04.01',
#   '02.03',
#   '02.03.01',
#   '02.03.01.01',
#   '02.03.01.02',
#   '02.03.02',
#   '02.03.02.01',
#   '02.03.02.02',
#   '02.03.02.09',
#   '02.03.03',
#   '02.03.04',
#   '02.03.04.01',
#   '02.03.04.02',
#   '02.03.04.03',
#   '02.03.04.09',
#   '02.03.05',
#   '02.03.06',
#   '02.03.06.01',
#   '02.03.06.02',
#   '02.03.06.09',
#   '02.03.07',
#   '02.03.08',
#   '02.03.09',
#   '03.01',
#   '03.02',
#   '03.03',
#   '03.04',
#   '03.04.01',
#   '03.04.01.01',
#   '03.05',
#   '03.06',
#   '03.07',
#   '03.08',
#   '03.11',
#   '03.11.01',
#   '03.11.02',
#   '06.01',
#   '06.02',
#   '06.03',
#   '07.01',
#   '07.01.01',
#   '07.01.02',
#   '07.01.03',
#   '07.01.04',
#   '07.02',
#   '07.02.01',
#   '07.02.02',
#   '07.02.03',
#   '07.02.04',
#   '07.03',
#   '07.04',
#   '07.04.01',
#   '07.04.02',
#   '07.05',
#   '07.06',
#   '07.06.01',
#   '07.06.02',
#   '07.06.03',
#   '07.06.03.01',
#   '07.06.03.02',
#   '07.07',
#   '07.08',
#   '07.08.01',
#   '07.08.01.01',
#   '07.08.01.02',
#   '07.08.01.03',
#   '07.08.01.04',
#   '07.08.02',
#   '07.08.02.01',
#   '07.08.02.02',
#   '07.08.02.03',
#   '07.08.03',
#   '07.08.03.01',
#   '07.08.03.02',
#   '07.08.03.03',
#   '07.08.04',
#   '07.08.04.01',
#   '07.08.04.02',
#   '07.08.04.03',
#   '07.08.04.04',
#   '07.08.05.01',
#   '07.08.05.02',
#   '07.08.05.03',
#   '07.08.05.04',
#   '07.08.05.09',
#   '99.3',
#   '99.4'],
#  'description': ['Ajustes Acumulados de Conversão',
#   'Ajustes Patrimoniais',
#   'Ajustes de Avaliação Patrimonial',
#   'Aluguéis',
#   'Aplicações Financeiras de Curto Prazo',
#   'Aplicações Líquidas de Curto Prazo',
#   'Aplicações a Valor Justo de Curto Prazo',
#   'Aplicações a Valor Justo de Longo Prazo',
#   'Aplicações ao Custo Amortizado de Curto Prazo',
#   'Ativo Circulante de Curto Prazo',
#   'Ativo Não Circulante de Longo Prazo',
#   'Ativo Realizável a Longo Prazo',
#   'Ativo Total',
#   'Ativos Biológicos de Curto Prazo',
#   'Ativos Biológicos de Longo Prazo',
#   'Atribuído a Sócios Não Controladores',
#   'Atribuído a Sócios da Empresa Controladora',
#   'Ações ON Ordinárias',
#   'Ações Ordinárias (ON)',
#   'Ações PN Preferenciais',
#   'Ações Preferenciais (PN)',
#   'Ações, Remuneração e Opções',
#   'Benefícios',
#   'Caixa de Financiamento',
#   'Caixa de Investimento',
#   'Caixa de Operações (Operacional)',
#   'Caixa e Bancos de Curto Prazo',
#   'Caixa e Equivalentes de Caixa de Curto Prazo',
#   'Capital Social',
#   'Capital Social Realizado',
#   'Carteira de Clientes',
#   'Clientes',
#   'Contas a Receber de Curto Prazo',
#   'Contas a Receber de Longo Prazo',
#   'Contas de Clientes de Curto Prazo',
#   'Créditos com Partes Relacionadas de Longo Prazo',
#   'Créditos de Liquidação Duvidosa',
#   'Custo dos Bens e/ou Serviços Vendidos',
#   'Custos Prods., Mercs. e Servs. Vendidos',
#   'Debêntures',
#   'Depreciação, Amortização e Exaustão',
#   'Derivativos e Participações',
#   'Despesas Antecipadas de Curto Prazo',
#   'Despesas Antecipadas de Longo Prazo',
#   'Despesas Comerciais',
#   'Despesas Operacionais',
#   'Despesas/Receitas Operacionais',
#   'Direito de Uso em Arrendamento',
#   'Distribuição do Valor Adicionado',
#   'Dividendos',
#   'Dividendos e Ações',
#   'Dividendos e Ações em Tesouraria',
#   'Débitos com Coligadas',
#   'Débitos com Controladores',
#   'Débitos com Outras Partes Relacionadas',
#   'Em Moeda Estrangeira',
#   'Em Moeda Nacional',
#   'Em Tesouraria Ações ON Ordinárias',
#   'Em Tesouraria Ações PN Preferenciais',
#   'Empréstimos e Financiamentos',
#   'Empréstimos e Financiamentos de Curto Prazo',
#   'Empréstimos e Financiamentos de Longo Prazo',
#   'Estaduais',
#   'Estoques de Curto Prazo',
#   'Estoques de Longo Prazo',
#   'Estoques de Material de Consumo de Curto Prazo',
#   'Estoques de Material para Revenda de Curto Prazo',
#   'Estoques de Outros Itens de Curto Prazo',
#   'F.G.T.S.',
#   'Federais',
#   'Financiamento por Arrendamento Financeiro',
#   'Fornecedores Estrangeiros',
#   'Fornecedores Nacionais',
#   'Fornecedores de Curto Prazo',
#   'Gastos na emissão de ações',
#   'Goodwill',
#   'Imobilizado',
#   'Imobilizado em Operação',
#   'Imposto de Renda e Contribuição Social Diferidos',
#   'Imposto de Renda e Contribuição Social a Pagar',
#   'Imposto de Renda e Contribuição Social sobre o Lucro',
#   'Impostos, Taxas e Contribuições',
#   'Insumos Adquiridos de Terceiros',
#   'Intangíveis',
#   'Intangível',
#   'Investimento Social',
#   'Investimentos',
#   'Juros',
#   'Juros sobre o Capital Próprio',
#   'Lucro do Período',
#   'Lucros Retidos',
#   'Lucros Retidos / Prejuízo do Período',
#   'Lucros/Prejuízos Acumulados',
#   'Marcas e Patentes',
#   'Materiais, Energia, Servs. de Terceiros e Outros',
#   'Municipais',
#   'Obrigações Fiscais Estaduais',
#   'Obrigações Fiscais Federais',
#   'Obrigações Fiscais Municipais',
#   'Obrigações Fiscais de Curto Prazo',
#   'Obrigações Sociais',
#   'Obrigações Trabalhistas',
#   'Obrigações Tributárias e Autorizações',
#   'Outras',
#   'Outras Contas de Curto Prazo',
#   'Outras Obrigações Fiscais Federais',
#   'Outras Obrigações de Curto Prazo',
#   'Outras Provisões',
#   'Outras Receitas',
#   'Outros',
#   'Outros Ativos Circulantes de Curto Prazo',
#   'Outros Ativos Circulantes de Longo Prazo',
#   'Outros Resultados Abrangentes',
#   'Part. Não Controladores nos Lucros Retidos',
#   'Participação Minoritária',
#   'Participação dos Acionistas Não Controladores',
#   'Participações Societárias',
#   'Participações em Coligadas',
#   'Participações em Controladas',
#   'Passivo Circulante de Curto Prazo',
#   'Passivo Não Circulante de Longo Prazo',
#   'Passivo Total',
#   'Passivos com Partes Relacionadas',
#   'Passivos com Partes Relacionadas de Longo Prazo',
#   'Patrimônio Líquido',
#   'Perda/Recuperação de Valores Ativos',
#   'Perdas e Aquisições com Não Controladores',
#   'Pessoal',
#   'Propriedades para Investimento',
#   'Provisão/Reversão de Créds. Liquidação Duvidosa',
#   'Provisões Cíveis',
#   'Provisões Fiscais',
#   'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis',
#   'Provisões Judiciais',
#   'Provisões Previdenciárias e Trabalhistas',
#   'Provisões de Curto Prazo',
#   'Provisões de Longo Prazo',
#   'Provisões para Benefícios a Empregados',
#   'Provisões para Garantias',
#   'Provisões para Passivos Ambientais e de Desativação',
#   'Provisões para Reestruturação',
#   'Provisões trabalhistas e cíveis, líquidas',
#   'Receita de Venda de Bens e/ou Serviços',
#   'Receitas',
#   'Receitas Financeiras',
#   'Receitas refs. à Construção de Ativos Próprios',
#   'Remuneração Direta',
#   'Remuneração de Capitais Próprios',
#   'Remuneração de Capitais de Terceiros',
#   'Reservas Legais e Estatutárias',
#   'Reservas de Capital',
#   'Reservas de Lucros',
#   'Reservas de Reavaliação',
#   'Resultado Antes do Resultado Financeiro e dos Tributos',
#   'Resultado Antes dos Tributos sobre o Lucro',
#   'Resultado Bruto',
#   'Resultado Financeiro',
#   'Resultado de Equivalência Patrimonial',
#   'Retenção de Lucros e Incentivos Fiscais',
#   'Retenções',
#   'Softwares',
#   'Telecomunicações e Consignações',
#   'Tributos Parcelados',
#   'Tributos a Recuperar de Curto Prazo',
#   'Tributos a Recuperar de Longo Prazo',
#   'Valor Adicionado Bruto',
#   'Valor Adicionado Líquido Produzido',
#   'Valor Adicionado Total a Distribuir',
#   'Vendas de Mercadorias, Produtos e Serviços',
#   'Vlr Adicionado Recebido em Transferência',
#   'Ágio e Reserva Especial']}

# %% [markdown]
# ### Bovespa Data

# %%
def parse_company_data(url, base_url='https://bvmf.bmfbovespa.com.br/sig/'):
    response = requests.get(url, headers=header_random(), verify=False)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the relevant table
        table = soup.find('table', {"width": "95%"})
        
        # Initialize lists to store data
        company_name = []
        trading_name = []
        listing = []
        ticker = []
        # url_mercado = []
        
        if table:
            # Iterate through rows of the table and extract data
            for row in table.find_all('tr')[1:]:  # Skip the header
                columns = row.find_all('td')
                
                # Check if the row has enough columns
                if len(columns) >= 4:
                    company_name.append(clean_text(columns[0].text.strip()))  # Razão Social
                    trading_name.append(clean_text(columns[1].text.strip()))   # Nome de Pregão
                    listing.append(clean_text(columns[2].text.strip()))  # Tipo de Mercado
                    ticker.append(clean_text(columns[3].text.strip()))         # Sigla
                    
                    # # Extract the link
                    # link = columns[0].find('a')['href']
                    # full_link = f"{base_url}{link}"
                    # url_mercado.append(full_link)
        
        # Return the extracted data as a DataFrame
        df = pd.DataFrame({
            'company_name': company_name,
            'trading_name': trading_name,
            'ticker': ticker,
            'listing': listing,
            # 'url_mercado': url_mercado
        })
        df['listing'] = df['listing'].map(settings.governance_levels).fillna(df['listing'])

    else:
        df = pd.DataFrame()

    return df

# %%
def get_companies_listing():
    try:
        from requests.packages.urllib3.exceptions import InsecureRequestWarning

        # Ignorar avisos de SSL (opcional)
        requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

        # List of characters A-Z and 0-9
        chars = list(string.digits) + list(string.ascii_uppercase)

        # Generate URLs based on each character
        base_urls = [f'https://bvmf.bmfbovespa.com.br/sig/FormConsultaEmpResultado.asp?strLetraInicial={char}' for char in chars]

        # Initialize an empty DataFrame to store all companies
        dfs = []

        # Iterate through each URL and fetch the data
        start_time = time.time()
        for i, url in enumerate(base_urls):
                # companies from url
                df = parse_company_data(url)
                dfs.append(df)

                extra_info = [url, f'{len(df)} companies listed']
                print_info(i, extra_info, start_time, len(base_urls))

        # DataFrame with all companies
        companies = pd.concat(dfs, ignore_index=True)

    except requests.exceptions.RequestException as e:
        companies = pd.DataFrame()


    return companies

# %%
def fetch_stock_info(soup):
    stock_info = {}

    # Locate the rows with "Nome da Ação" to get stock name and ticker
    stock_rows = soup.find_all('td', class_='tittabela', colspan="7")

    for row in stock_rows:
        stock_text = row.get_text(strip=True)
        if "Nome da Ação" in stock_text:
            # Extract the stock name and ticker (in parentheses)
            stock_name = stock_text.split("(")[0].replace("Nome da Ação:", "").strip()
            stock_ticker = stock_text.split("(")[1].replace(")", "").strip()
            
            # Add stock_name and stock_ticker to the dictionary
            stock_info[stock_name] = stock_ticker
    return stock_info

# %%
def get_pages_to_download(companies, start_date):
    tipo = 'RES_MERC_VISTA'

    date_range = [date.strftime('%m-%Y') for date in pd.date_range(start=start_date, end=pd.Timestamp.today() - pd.offsets.MonthEnd(1), freq='MS')]

    # Generate the items list with ticker, company_name, trading_name, and date
    items = [[row['ticker'], row['company_name'], row['trading_name'], mes] 
            for _, row in companies.iterrows() 
            for mes in date_range]
    
    return items

# %%
# Helper function to convert text with '.' as thousand separator and ',' as decimal separator
def convert_to_float(value):
    try:
        # Remove thousand separator and replace decimal separator
        return float(value.replace('.', '').replace(',', '.'))
    except ValueError:
        return None

def convert_to_int(value):
    try:
        # Remove thousand separator and convert to int
        return int(value.replace('.', '').replace(',', ''))
    except ValueError:
        return None
def fetch_trades(soup, stock_info, ticker_code, company_name, trading_name, date):
    data = []
    
    # Find all tables that contain daily trading information
    tables = soup.find_all('table')
    
    for table in tables:
        rows = table.find_all('tr')

        for row in rows:
            columns = row.find_all('td')
            if len(columns) == 12:  # Ensure the row has the expected number of columns
                dia = columns[0].get_text(strip=True)
                especif = columns[1].get_text(strip=True)

                # Convert trades, quantity, and volume to int
                trades = convert_to_int(columns[2].get_text(strip=True))
                quantity = convert_to_int(columns[4].get_text(strip=True))
                volume = convert_to_int(columns[5].get_text(strip=True))

                # Convert open, low, high, average, close to float
                open = convert_to_float(columns[7].get_text(strip=True))
                low = convert_to_float(columns[8].get_text(strip=True))
                high = convert_to_float(columns[9].get_text(strip=True))
                average = convert_to_float(columns[10].get_text(strip=True))
                close = convert_to_float(columns[11].get_text(strip=True))

                # Filter out unwanted rows based on some patterns
                if "Negociações" in dia or "Dia" in dia or "Total" in dia:
                    continue  # Skip unwanted rows

                # Combine 'dia' with 'mes' to create a full date
                full_date = pd.to_datetime(f"{dia}-{date}", format="%d-%m-%Y")

                # Split 'Especif.' into stock code and listing
                parts = especif.split()

                # Map 'ticker_code' from the first part (stock_name) using stock_info
                ticker_ = parts[0]
                ticker = stock_info.get(ticker_, ticker_)  # Map or fallback to stock_code
                ticker_number = ''.join([char for char in ticker if char.isdigit()])

                # Extract 'listing' if available
                listing = parts[1] if len(parts) > 1 else None

                if listing == '*':
                    trades = trades * 10 # (transformar lotes de mil em 10 lotes de 100)
                    listing = ''

                # Map 'listing' using the governance_levels dictionary
                if listing in settings.governance_levels:
                    listing = settings.governance_levels[listing]

                # Append row data to the list
                data.append({
                    'company_name': company_name,
                    'trading_name': trading_name,
                    'ticker_code': ticker_code + ticker_number,
                    'date': full_date,
                    'listing': listing,
                    'trades': trades, 
                    'quantity': quantity, 
                    'volume': volume, 
                    'open': open, 
                    'low': low, 
                    'high': high, 
                    'average': average, 
                    'close': close, 
                })
    
    df = pd.DataFrame(data).drop_duplicates()
    return df

# %%
settings.db_filepath

# %%
db_file = f"..\data\{settings.db_filepath}"

conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# %%
companies.info()

# %%
# Generate the date range from January 1996 to the current month
start_date = '1991-01'
# start_date = '1986-01'
start_date = '1997-01' # temp debug


companies = get_companies_listing()
pages = get_pages_to_download(companies, start_date)
error_url = []

# %%
tipo = 'RES_MERC_VISTA'

dfs = []

start_time = time.time()
for i, (ticker_code, company_name, trading_name, date) in enumerate(items):
    if [ticker_code, date] not in error_url:

        # debug skip
        if 'BRSR' not in ticker_code:
            continue

        # Fetch the webpage content
        url = f'https://bvmf.bmfbovespa.com.br/sig/FormConsultaMercVista.asp?strTipoResumo={tipo}&strSocEmissora={ticker_code}&strDtReferencia={date}&strIdioma=P&intCodNivel=2&intCodCtrl=160'
        try:
            # get page response
            response = requests.get(url, headers=header_random(), verify=False)

            if response.status_code == 200:
                # Parse the HTML using BeautifulSoup
                soup = BeautifulSoup(response.text, 'html.parser')

                # Check if page has target content
                stock_info = fetch_stock_info(soup)

                # if page has target content, get data
                if stock_info:
                    df = fetch_trades(soup, stock_info, ticker_code, company_name, trading_name, date)
                    dfs.append(df)

                    # print status
                    extra_info = [ticker_code, date, url]
                    print_info(i, extra_info, start_time, len(items))
                    if i == 129499:
                        break
                
                # if not target content, add to error list
                else:
                    error_url.append([ticker_code, date])

                    # print status
                    extra_info = [ticker_code, date]
                    print_info(i, extra_info, start_time, len(items))

            # if response error
            else:
                print(f"Failed to fetch the page. Status code: {response.status_code}, {i}")

        except requests.exceptions.RequestException as e:
            print(f"Error requesting {ticker_code}, {date}: {e}")

    # if already checked item for error
    else:
        print(ticker_code, date)
        pass

# %%
pd.concat(dfs)

# %%
import requests
from bs4 import BeautifulSoup

# Example variables
tipo = 'RES_MERC_VISTA'
ticker = 'BRSR'  # Replace this with a value from companies['ticker']
mes = '04/2017'

# Build the base URL
base_url = f'https://bvmf.bmfbovespa.com.br/sig/FormConsultaMercVista.asp?strTipoResumo={tipo}&strSocEmissora={ticker}&strDtReferencia={mes}&strIdioma=P&intCodNivel=2&intCodCtrl=160'

# Fetch the webpage content
try:
    response = requests.get(base_url, headers=header_random(), verify=False)
    if response.status_code == 200:
        # Parse the HTML using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        print(f"URL: {base_url} - Status: {response.status_code} - Success")

        # Locate the tables by finding the table with id "tblResDiario"
        tables = soup.find_all('table', {"id": "tblResDiario"})

    else:
        print(f"Failed to fetch the page. Status code: {response.status_code}")

except requests.exceptions.RequestException as e:
    print(f"Error requesting {base_url}: {e}")

# %%
if 1 == 1:
    stock_info = {}

    # Locate the rows with "Nome da Ação" to get stock name and ticker
    stock_rows = soup.find_all('td', class_='tittabela', colspan="7")
    
    for row in stock_rows:
        stock_text = row.get_text(strip=True)
        if "Nome da Ação" in stock_text:
            # Extract the stock name and ticker (in parentheses)
            stock_name = stock_text.split("(")[0].replace("Nome da Ação:", "").strip()
            stock_ticker = stock_text.split("(")[1].replace(")", "").strip()
            
            # Add stock_name and stock_ticker to the dictionary
            stock_info[stock_name] = stock_ticker

stock_info

# %%
# Parsing the table data
if 1 == 1:

# Create a DataFrame and remove duplicates
df = pd.DataFrame(data).drop_duplicates()

# Display the DataFrame
df.iloc[:60]
